# %% [markdown]
# # ¿Por qué Python?

# %% [markdown]
# Es uno de los lenguajes de programación con reglas más simples e intuitivas que existen; esto explica la creciente popularidad que ha tenido en los últimos tiempos.
#
# No obstante a su simpleza, es muy utilizado tanto en la industria como en el área académica; para servidores y servicios web, despliegue de modelos, redes neuronales, deep learning, simulación, análisis de datos, etc.
#
# La comunidad de Python es una de las más grandes.

# %% [markdown]
# **PopularitY of Programming Language** (PYPL)
#
# https://pypl.github.io/PYPL.html
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Variables

# %% [markdown]
# Existen distintos tipos de variables:
# - int: entero
# - float: punto flotante
# - string: cadena de caracteres
# - bool: booleano, 0, 1, True o False
# - complex: complejos
#
# Y estructuras de datos, como:
#   - list: lista de elementos (de cualquier tipo, incluida otra lista)
#   - dict: "diccionario", conjunto de pares llave:valor
#
#   - set
#   - tuple ...

# %%
variable = 'Hola mundo'
print(variable) # Imprime la representación en string de la variable
# Out:
# Hola mundo

# %%
variable = str(123)
print(variable)
# Out:
# 123

# %%
type(variable) # Tipo de la variable
# Out:
# str

# %% [markdown]
# ## Numéricas

# %% [markdown]
# Ejemplos de operaciones elementales

# %%
a = 2
b = 5

# %%
print(a + b) # suma
print(a * 2) # multiplicación
print(a ** (1/2)) # potencia/raiz
# Out:
# 7
# 4
# 1.4142135623730951

# %%
print(b / a)  # división
print(b // a) # división entera
print(b % a)  # resto de la división entera
# Out:
# 2.5
# 2
# 1

# %% [markdown]
# ## Booleanas

# %% [markdown]
# Los operadores disponibles son:
#
#     Relacionales:
#     - >= , <=, <, > : Mayor o igual, menor o igual, mayor o menor
#     - != , == : Distinto, Igual
#     - in : Contenido por
#     Lógicos:
#     - not o ~ : Negación
#     - and o & : Ambas verdaderas
#     - or o | : Una u otra es verdadera
#
# Como booleanos, se pueden utilizar tanto 0 y 1 como True y False.

# %%
print(a >= b)
# Out:
# False

# %%
print("palabra" == "palabra")
print("otras palabra" != "otras palabras")
# Out:
# True
# True

# %%
print('test' in "testing")  # Preguntá si 'test' está contenido en 'testing'

arreglo = 'cosas_estaacá_mascosas'

print('esta' in arreglo)    # Ídem, lo que se busca puede estar en cualquier parte
# Out:
# True
# True

# %%
arreglo = 'cosas_no3staacá_mascosas'

print('esta' in arreglo)
# Out:
# False

# %% [markdown]
# ## Strings

# %%
"dos strings se pueden " + "sumar"
# Out:
# 'dos strings se pueden sumar'

# %% [markdown]
# Podemos acceder a elementos particulares mediante **índices**. Los mismos funcionan para cualquier **iterable**, que es un objeto con muchos elementos que son accesibles secuencialmente. Podemos usar los índices para acceder a una posición determinada, pasándola entre corchetes [posición]. Es IMPORTANTE mencionar que en Python la primera posición tiene el índice 0 (y no 1).

# %%
texto = "programación en python"
texto[0]
# Out:
# 'p'

# %% [markdown]
# También podemos usar los índices para traer más de un elemento al mismo tiempo, usando el **slicing**. El slicing lleva tres parámetros: comienzo (start), final (stop) e intervalo o paso (step).
#
# - El parámetro comienzo (start) indica la primera posición incluida en la selección, por default es 0.
#
# - El parámetro final (stop) es la primera posición que NO va a estar incluída, por default se incluyen todos los elementos.
#
# - El parámetro intervalo o paso (step), es optativo e indica el tamaño del paso entre seleccionar un elemento y el siguiente, por default el paso es 1. El paso también puede ser negativo, en este caso contamos desde el final hacia el comienzo, esto es muy útil para dar vuelta los strings o otro tipo de iterables ordenados.
#
#
#     [start : stop : step]

# %%
texto[:]
# Out:
# 'programación en python'

# %%
texto[:1]
# Out:
# 'p'

# %%
texto[1:4]
# Out:
# 'rog'

# %%
texto[::-1]
# Out:
# 'nohtyp ne nóicamargorp'

# %%
texto[-1]
# Out:
# 'n'

# %% [markdown]
# ### Métodos...

# %%
type(texto)
# Out:
# str

# %%
texto.upper()
# Out:
# 'PROGRAMACIÓN EN PYTHON'

# %%
texto.title()
# Out:
# 'Programación En Python'

# %%
texto.split() # Devuelve una lista, de ésto vamos a hablar a continuación
# Out:
# ['programación', 'en', 'python']

# %% [markdown]
# Pequeño ejemplo de aplicación

# %%
linea_de_un_csv = "123;1.2;9"

# %%
linea_de_un_csv.split(";")
# Out:
# ['123', '1.2', '9']

# %% [markdown]
# Otras "facilidades"... desempaquetado

# %%
a, b, c = linea_de_un_csv.split(";")

# %%
print("Los valores son: {}, {} y {}. Ahora los tengo separados para operar.".format(a, b, c))
# Out:
# Los valores son: 123, 1.2 y 9. Ahora los tengo separados para operar.

# %%
print(a+b)  # Qué pasa acá? Concatenación de variables del tipo 'string'
# Out:
# 1231.2

# %% [markdown]
# El tipado es dinámico en Python, necesito forzar o transformar el tipo de la variable para operaciones determinadas.

# %%
a = int(a)
b = float(b)
print(a+b) # Ahora la operación es matemática (variables numéricas)
# Out:
# 124.2

# %% [markdown]
# ## Listas

# %% [markdown]
# Las listas son un conjunto de elementos ordenados. Estos elementos pueden ser de cualquier tipo, incluyendo otras listas.
#
# Doc.: https://docs.python.org/3/tutorial/datastructures.html

# %%
amigos = ['Mateo', 'Matías', 'Sergio', 'Javier', 'Eduardo']

# %% [markdown]
# De la misma forma que con los strings en el contexto de la listas generalmente hablamos de **indexación** o acceso por índice a la acción de encontrar un valor según su posición en la lista.

# %%
amigos[0]
# Out:
# 'Mateo'

# %%
amigos[-1] # Podemos comenzar desde "atrás"
# Out:
# 'Eduardo'

# %%
amigos[::2] # salteamos un elemento a la vez
# Out:
# ['Mateo', 'Sergio', 'Eduardo']

# %%
type(amigos)
# Out:
# list

# %% [markdown]
# ### Métodos específicos

# %%
amigos.remove('Mateo')  # Borrado por valor
amigos
# Out:
# ['Matías', 'Sergio', 'Javier', 'Eduardo']

# %%
amigos.append('Mateo')  # Agregado nuevo valor, al final
amigos
# Out:
# ['Matías', 'Sergio', 'Javier', 'Eduardo', 'Mateo']

# %%
amigos.pop(3)  # Borrado por índice
amigos
# Out:
# ['Matías', 'Sergio', 'Javier', 'Mateo']

# %%
amigos.insert(3, "Eduardo") # Agregado nuevo valor, en índice específico
amigos
# Out:
# ['Matías', 'Sergio', 'Javier', 'Eduardo', 'Mateo']

# %%
amigos.sort()  # Ordenado de la lista, son 'strings' los elementos. Notar que asume un criterio para ordenar palabras, en este caso es el orden alfabético
amigos
# Out:
# ['Eduardo', 'Javier', 'Mateo', 'Matías', 'Sergio']

# %%
amigos.sort(reverse=True)  # Por defecto es descendente, puedo invertirlo
amigos
# Out:
# ['Sergio', 'Matías', 'Mateo', 'Javier', 'Eduardo']

# %%
print("Actualmente tengo {} amigos.".format(len(amigos)))
# Out:
# Actualmente tengo 5 amigos.

# %% [markdown]
# Para valores numéricos resultan interesantes otros métodos...

# %%
numeros = [1 , -5.2, 66, -8.3 , 7, 1, 1]

# %%
print(min(numeros))
print(max(numeros))
# Out:
# -8.3
# 66

# %%
print(sum(numeros))
# Out:
# 62.5

# %%
print("El promedio es: ", sum(numeros)/len(numeros))
# Out:
# El promedio es:  8.928571428571429

# %%
numeros.count(1)  # La cantidad de unos que contiene la lista
# Out:
# 3

# %% [markdown]
# ## Diccionarios

# %% [markdown]
# Los diccionarios consisten en estructuras que contienen pares de una **llave** y un **valor**. Los elementos NO están ordenados, con lo cual no se puede acceder por posición ni slicing.

# %%
datos = {
        "llave" : "valor",
         1 : 2,
         "dni" : 123456789,
         "lista" : [1,2,3],
         False : "valor de False"
        }

# %% [markdown]
# Sin embargo, sí podemos acceder a un elemento por su llave.

# %%
datos["llave"]
# Out:
# 'valor'

# %%
datos[False]
# Out:
# 'valor de False'

# %%
datos["cualquier llave"]  # Se produce un error si se intenta recuperar un valor para una clave inexistente
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-854f53318fce> in <cell line: 1>()
# ----> 1 datos["cualquier llave"]  # Se produce un error si se intenta recuperar un valor para una clave inexistente
#
# KeyError: 'cualquier llave'

# %%
datos

# %%
datos.keys()    # Lista todas las llaves
# Out:
# dict_keys(['llave', 1, 'dni', 'lista', False])

# %%
datos.values()    # Lista todos los valores
# Out:
# dict_values(['valor', 2, 123456789, [1, 2, 3], 'valor de False'])

# %% [markdown]
# ## Tuplas

# %% [markdown]
# Una **tupla** es una secuencia **inmutable** de longitud fija. Las tuplas generalmente se utilizan para representar secuencias de elementos que tienen longitud fija.

# %%
registro = ('Argentina', 1280960, 'Misiones')

# %% [markdown]
# Podemos acceder a un elemento por un índice como con una lista.

# %%
registro[0]
# Out:
# 'Argentina'

# %% [markdown]
# Como las tuplas son **inmutables** no se pueden modificar

# %%
registro[0] = 'Brasil'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-63-ce1fb9c9bad6> in <cell line: 1>()
# ----> 1 registro[0] = 'Brasil'
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ### Desempaquetamiento

# %% [markdown]
# Con una tupla podemos separar una secuencia en variables de la siguiente manera:

# %%
pais, poblacion, provincia = registro

print("País:", pais)
print("Población:", poblacion)
print("Provincia:", provincia)
# Out:
# País: Argentina
# Población: 1280960
# Provincia: Misiones

# %% [markdown]
# Este concepto se aplica *in situ* en demás operaciones. Por dar un ejemplo, se pueden intercambiar valores en variables de la siguiente manera:

# %%
a = 3
b = 2

a, b = b, a
print(a, b)
# Out:
# 2 3

# %% [markdown]
# O directamente en la asignación:

# %%
a, b, c = 1, 2, "string"

# %% [markdown]
# Esto es, porque por defecto, valores separados por coma son tratados como tuplas en Python.

# %% [markdown]
# # Condicionales

# %% [markdown]
# El condicional tiene la siguiente sintáxis:
#
#     if CONDICIÓN:
#         código1
#     elif CONDICIÓN2:
#         código2
#     else:
#         código3
#
# Donde la condición es un operador que devuelve un objeto de tipo booleano. La **indentación** del código define qué parte se incluye como condicional.
#
# El término "elif" viene de "else if". La condición sólo se evaluará si la condición del "if" no se cumple.

# %%
valor = 300

if valor > 500:
    print("El valor es superior a 500.")
elif 200 < valor < 500:
    print("El valor se encuentra entre 200 y 500.")
else:
    print("El valor es menor a 200.")
# Out:
# El valor se encuentra entre 200 y 500.

# %% [markdown]
# # Bucles

# %% [markdown]
# ## For

# %%
lista = [1, 3, "hola", False, 3.2]

for i in lista:
    print(i)
# Out:
# 1
# 3
# hola
# False
# 3.2

# %%
for i in range(0,5,2):
    print(i)
# Out:
# 0
# 2
# 4

# %% [markdown]
# La función *range* consta de tres parámetros importante: *start*, *stop*, *step*. Si pasamos un sólo parámetro, estamos pasando el "stop" y tomamos 0 como valor default de "start". Del mismo modo que cuando vimos listas, el stop no está incluído y el step por default es 1. El tercer parámetro es el "step", por defecto se encuentra en 1.

# %%
for i in range(1, 10, 2):
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %% [markdown]
# Podemos iterar sobre objetos que son iterables (valga la redundancia)

# %%
for a in "palabra":
    print(a)
# Out:
# p
# a
# l
# a
# b
# r
# a

# %%
for b in datos.keys():
    print(b)
# Out:
# llave
# 1
# dni
# lista
# False

# %% [markdown]
# ## While

# %%
mostrar = 5
palabra = "introducción"

i = 0
while i < mostrar:
    print(palabra[i])
    i += 1
# Out:
# i
# n
# t
# r
# o

# %%
i = 0
while True:
    if palabra[i] != "c":
        print(palabra[i])
    else:
        print("Finalizando el bucle...")
        break   # rompe el bucle

    i += 1
# Out:
# i
# n
# t
# r
# o
# d
# u
# Finalizando el bucle...

# %% [markdown]
# ## Comprensión de listas

# %% [markdown]
# Pequeño ejemplo comparativo respecto a la utilización de bucles tradicionales.
#
# Objetivo: obtener los cuadrados de los números almacenados en una lista.

# %%
originales = [1, 2, 3, 4, 5]
cuadrados = []

for i in originales:
    cuadrados.append(i**2)

print(cuadrados)
# Out:
# [1, 4, 9, 16, 25]

# %%
# Por list comprehension sería
originales = [1, 2, 3, 4, 5]
cuadrados = [i**2 for i in originales]

print(cuadrados)
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# No parece muy diferente, pero es mucho más eficiente.
#
# Pequeño ejemplo extendiendo el tamaño de los datos a tratar:

# %%
from timeit import default_timer as timer  # Librería del núcleo de Python para medición del tiempo

# %%
inicio = timer()
### Inicio Tarea a medir ###
originales = list(range(5000000))
cuadrados = []

for i in originales:
    cuadrados.append(i**2)
### Fin Tarea a medir ###
total = timer()-inicio
print("Duración: {} s".format(total))
# Out:
# Duración: 2.32865371600019 s

# %%
inicio = timer()
### Inicio Tarea a medir ###
originales = list(range(5000000))
cuadrados = []

cuadrados = [i**2 for i in originales]
### Fin Tarea a medir ###
total = timer()-inicio
print("Duración: {} s".format(total))
# Out:
# Duración: 1.9281113659999392 s

# %% [markdown]
# # Funciones

# %% [markdown]
# Las funciones se definen de la siguiente manera:
#
#     def nombre_de_funcion(argumentos):
#         """docstring opcional"""
#         resultado = procedimiento(argumentos)
#         return resultado
#
# Las variables definidias en el contexto de una función son locales, es decir, sólo viven dentro de esa función. Por otra parte, si desde una función se llama a una variable que no está definida en la función tratará de buscarla afuera. En general, es buena práctica usar sólo variables definidas dentro de la función o argumentos.
#
# Los argumentos son variables que le pasamos a la función para que *haga algo*.
#
# Las funciones emplean dos términos reservados:
#
# - def: que indica el comienzo de la definición de la función
#
# - return: establece la variable o variables que devuelve la función
#
# En este punto vale la pena mencionar que en Python los nombres (de variables, funciones, etc.) se almacenan y ordenan en NameSpaces. En este punto, la información definida dentro de la función no es compartida con el exterior de la función (salvo algunas excepciones que no vienen al caso), por lo tanto, para compartirla, la función debe enviar desde el NameSpace local (el de la función) al NameSpace global (donde está el resto del programa). Para ello, el término return indica qué se devolverá al ambiente global. Para que efectivamente esa/s variable/s que la función devuelve se guarden una variable en el ambiente global debemos asignar el resultado a una variable. Esto va a quedar más claro con el código.
#
# Por último, vale la pena mencionar que *print* sólo nos muestra el contenido de una variable pero no envía la información desde la función hacia afuera.

# %%
def suma(a,b):
    """Esta función recibe dos numeros y devuelve la suma"""
    return a + b

# %%
# prueba de la función suma
num1 = 15
num2 = 5
resultado = suma(num1, num2)

print(resultado)
# Out:
# 20

# %%
def rango(lista):
    """Esta función recibe una lista y devuelve su rango"""
    return max(lista) - min(lista)

# %%
# prueba de la función rango
lista = [3, 8, -3, 45, 8, 66]

print(rango(lista))
# Out:
# 69

# %% [markdown]
# ¿Qué pasa si el tipo de dato que envío como argumento no es el correcto?

# %%
print(rango(2))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-95-acbb7dfcd387> in <cell line: 1>()
# ----> 1 print(rango(2))
#
# <ipython-input-92-17f74f364ade> in rango(lista)
#       1 def rango(lista):
#       2     """Esta función recibe una lista y devuelve su rango"""
# ----> 3     return max(lista) - min(lista)
#
# TypeError: 'int' object is not iterable

# %% [markdown]
# Existe todo un marco para el control y manejo de excepciones. Lo vemos enseguida.

# %% [markdown]
# ## Argumentos por defecto

# %%
def mi_funcion_test(a, debug=False):
    """Esta función recibe un numeros y lo opera.
    debug: permite activar mensajes para el proceso de desarrollo.
    """
    if debug:
        print("Este mensaje se muestra solamente cuando el usuario lo indica explícitamente...")

    return a*2

# %%
print(mi_funcion_test(2))
# Out:
# 4

# %%
print(mi_funcion_test(2, True))
# Out:
# Este mensaje se muestra solamente cuando el usuario lo indica explícitamente...
# 4

# %%
print(mi_funcion_test(debug=True, a=2))
# Out:
# Este mensaje se muestra solamente cuando el usuario lo indica explícitamente...
# 4

# %% [markdown]
# ## Argumentos variables

# %% [markdown]
# Existen distintos tipos de argumentos, principalmente los llamados "args" y "kwargs", o argumentos y "keyword arguments" es decir argumentos nombrados.
#
# También podemos tener un numero variable de argumentos, usando el symbolo *, por conveción al parámetro se le llama 'args'
#
# Internamente, los elementos de *args se tratan como una tupla. Por lo tanto podemos desempaquetar, usarlo como iterador, etc.

# %% [markdown]
# Los elementos de **kwargs se tratan como un diccionario.

# %%
def sumar(*args):
    print(type(args))
    return sum(args)

# %%
resultado = sumar(1,4,9,8,5)
print(resultado)
# Out:
# <class 'tuple'>
# 27

# %% [markdown]
# ## Generadores

# %% [markdown]
# Un generador (Generator) es una función especial que se puede usar para generar una secuencia de valores para iterar sobre ellos a demanda. Para ello se utiliza la palabra clave **yield**. Esta palabra clave solo se puede utilizar dentro de una función o de un método.
#
# Cuando se ejecuta **yield**, la ejecución de la función se suspende y se devuelve el valor que acompaña a **yield**. La ejecución de la función generador se activará de nuevo en la siguiente llamada a partir del punto donde se suspendió.

# %%
def pares_consecutivos():
    actual = 0
    while True:
        yield actual
        actual += 2

pares_infinitos = pares_consecutivos()

# %%
print(next(pares_infinitos))
# Out:
# 6

# %%
pares_consecutivos()
# Out:
# <generator object pares_consecutivos at 0x78ae6921b060>

# %% [markdown]
# # Manejo de errores

# %% [markdown]
# Para anticipar y manejar los errores, podemos usar la clausula **try** y **except**.

# %%
a = "25"
b = 5

a+b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-111-5dcc6fb8d83a> in <cell line: 4>()
#       2 b = 5
#       3
# ----> 4 a+b
#
# TypeError: can only concatenate str (not "int") to str

# %%
a = "25"
b = 5

try:
    print(a+b)
    print("Se interpreta esta linea.")
except:
    print(int(a)+int(b)) # convierto a int ambas variables
    print("Arriba pasó algo, se interpretó esta linea.")
# Out:
# 30
# Arriba pasó algo, se interpretó esta linea.

# %%
try:
    print(a+b)
except Exception as e:
    print("El error fue {}".format(e))
# Out:
# El error fue can only concatenate str (not "int") to str

# %% [markdown]
# También podemos especificar qué hacer para distintos tipos de error:

# %%
lista_tuplas = [('3', 8),
                (5, 0),
                (3, ),
                (4, 6)]

for t in lista_tuplas:
    print(f"la tupla es {t}")

    try:
        print("intento dividir...")
        print(t[0] / t[1])
        print("éxito!")
    except IndexError:
        print('El largo está mal')
    except TypeError:
        print('Error en el tipo de datos')
    except ZeroDivisionError:
        print("No se puede dividir por cero")

    input("Continuar?")
# Out:
# la tupla es ('3', 8)
# intento dividir...
# Error en el tipo de datos
# Continuar?
# la tupla es (5, 0)
# intento dividir...
# No se puede dividir por cero
# Continuar?
# la tupla es (3,)
# intento dividir...
# El largo está mal
# Continuar?
# la tupla es (4, 6)
# intento dividir...
# 0.6666666666666666
# éxito!
# Continuar?

# %% [markdown]
# # Programación orientada a objetos

# %% [markdown]
# En el paradigma de programación orientada a objetos los programas se estructuran organizando el código en entidades llamadas objetos. Estos nos permiten encapsular datos, funciones y variables dentro de una misma clase.

# %% [markdown]
# ## Terminologia de clases y objetos

# %% [markdown]
# 1. Una **clase** es un prototipo de objeto, que engloba atributos que poseen todos los objetos de esa clase. Los atributos pueden ser datos como variables de clase y de instancia, y métodos (funciones). Se acceden con un punto.
#
# 2. Una **instancia** es un objeto en particular que pertenece a una clase.
#
# 3. Los **atributos** son variables asociadas a los objetos. Los atributos pueden ser de clase (toman el mismo valor para toda la clase) o de instancia (toman un valor diferente para cada instancia). Lo más común de utilizar son los atributos de instancia que reflejan estados de los objetos. Los atributos de clase se utilizan para que todos los objetos compartan por ejemplo, las mismas configuraciones.
#
# 4. La **herencia** es la transferencia de atributos de una clase a otra clase.
#
# 5. Un **método** es una función contenida dentro de un objeto.
#
# 6. Un **objeto** es una instancia única de una estructura definida por su clase. Posee de atributos variables de clase, de instancia y métodos.
#
# 7. El **polimorfismo** nos permite utilizar una misma función para distintos tipos de datos o clases.
#
# 8. La **delegación** es el concepto con el cual podemos delegar tareas de una clase sobre algún método de otra clase.

# %% [markdown]
# ## Primer clase

# %% [markdown]
# Podemos pensar a una clase como un "molde", el cual usamos para generar objetos o instancias que tienen ciertos atributos o métodos (funciones) que deseamos mantener.
#
# Aquellos atributos y métodos que queremos que los objetos conserven son definidos como parte del constructor. El constructor en Python es el método reservado `__init__()`. Este método se llama cuando se instancia la clase y en ese momento se inicializan los atributos de la clase, para lo cual podemos pasar parámetros.
#
# Además, vamos a emplear el término reservado (por convención) *self* para indicar aquellos atributos y métodos que van a ser propios de la instancia.

# %%
class Persona():
    def __init__(self, nombre, apellido, edad, contacto=None):
        # Este método puede tomar parámetros que asignamos a los atributos, que luego podemos acceder
        self.edad = edad # este es un atributo
        self.contacto = contacto # este es otro atributo
        self.nombre = nombre
        self.apellido = apellido

    def nombre_completo(self):
        # este método devuelve el nombre completo a partir del nombre y apellido de la instancia
        nombre_completo = '{}, {}'.format(self.apellido, self.nombre)
        return nombre_completo

    def saludar(self):
        print('Hola mi nombre es {} y tengo {} años.'.format(self.nombre, self.edad))

# %%
instancia_ejemplo = Persona('Juan','Perez', 24, 'jp@rip.com')
instancia_ejemplo.saludar()
# Out:
# Hola mi nombre es Juan y tengo 24 años.

# %%
print(type(instancia_ejemplo))
# Out:
# <class '__main__.Persona'>

# %%
instancia_ejemplo.apellido  # Acceder a sus atributos internos
# Out:
# 'Perez'

# %%
print(instancia_ejemplo)

# %% [markdown]
# En Python existen los llamados métodos mágicos (`magic methods`) o dunder (`Double Underscores`). Estos métodos se caracterizan, justamente, por comenzar y terminar con "`__`". Uno de los más comunes es el que permite darle estilo a la función print. Para que nuestro objeto entonces tenga un lindo print tenemos que definir una función "`__str__`" que sólo toma "*self*" como parámetro y que retorne un string. Eso que retorna es el string que queremos que muestra cuando hagamos "print" del objeto.

# %%
class Persona():
    def __init__(self, nombre, apellido, edad, contacto=None):
        # Este método puede tomar parámetros que asignamos a los atributos, que luego podemos acceder
        self.edad = edad # este es un atributo
        self.contacto = contacto # este es otro atributo
        self.nombre = nombre
        self.apellido = apellido

    def nombre_completo(self):
        # este método devuelve el nombre completo a partir del nombre y apellido de la instancia
        nombre_completo = '{}, {}'.format(self.apellido, self.nombre)
        return nombre_completo

    def saludar(self):
        print('Hola mi nombre es {} y tengo {} años.'.format(self.nombre, self.edad))

    def __str__(self):
        return '{}-{}'.format(self.nombre.title(), self.apellido.title())

# %%
instancia_ejemplo = Persona('Juan','Perez', 24, 'jp@rip.com')
instancia_ejemplo.saludar()
# Out:
# Hola mi nombre es Juan y tengo 24 años.

# %%
print(instancia_ejemplo)  # Ahora el print es diferente
# Out:
# Juan-Perez

# %% [markdown]
# ## Herencia

# %% [markdown]
# La herencia se emplea cuando queremos que una clase tome los atributos y características de otra clase.
# En este caso, la clase derivada (Alumno) **hereda** atributos y métodos de la clase base (Persona).
# Para acceder a los métodos de la clase previa vamos a emplear el método reservado **super()**. Con este método podemos invocar el constructor y así acceder a los atributos de esa clase.

# %%
class Alumno(Persona):
    def __init__(self, *args):
        """
        Alumno pertence a un Curso (una instancia de la clase Curso) y, además, tiene otros atributos que pasaremos
        a la clase previa
        """
        self.conocimientos = [] # atributo nuevo, para la clase Alumno
        super().__init__(*args) # inicializamos la clase 'madre'. La llamamos usando super() y ejecutamos el constructor
        # Nótese también que desempaquetamos args

    def saludar(self): # Sobrecarga de métodos, ver abajo
        super().saludar() # ejecutamos el método de Persona .saludar() y agregamos más cosas a este método
        print('Además, soy alumno.')

    def estudiar(self, dato): # También podemos definir nuevos métodos
        self.conocimientos.append(dato)

    def repasar(self):
        for i in self.conocimientos:
            print("En su momento estudié: {}".format(i))

# %%
alumno_ejemplo = Alumno('Juan','Perez', 24, 'jp@rip.com')

# %%
alumno_ejemplo.saludar()
# Out:
# Hola mi nombre es Juan y tengo 24 años.
# Además, soy alumno.

# %%
alumno_ejemplo.estudiar("Álgebra")
alumno_ejemplo.estudiar("Química")

# %%
alumno_ejemplo.repasar()
# Out:
# En su momento estudié: Álgebra
# En su momento estudié: Química
# En su momento estudié: Álgebra
# En su momento estudié: Química

# %% [markdown]
# ## Protección de acceso

# %% [markdown]
# Podemos cambiar el acceso (publico, no publico, protejido) de los métodos y variables.
#
# Dos formas distintas de encapsulamiento:
#
# - `_nopublico`
# - `__protegido`
#
# Los atributos o método no públicos pueden ser accedidos desde el objeto y llevan el prefijo "\_". La utilidad de este es indicarle al usuario que es una variable o método privado, de uso interno en el código de la clase y que no está pensando que sea usado desde afuera, por el usuario.
#
# Por otra parte, en el caso de usar como prefijo "\_\_" (doble "\_") directamente vamos a ocultar la variable o método de la lista de sugerencias para el usuario y tampoco va a poder invocarlo desde el objeto. Por este motivo, decimos que el atributo o método está protegido.

# %% [markdown]
# ## *Duck typing* y *monkey patching*

# %% [markdown]
# Dos características de la programación orientada a objetos con Python son el *duck tiping* y el *monkey patching*. Este tipo de flexibilidad es el que le permitió a Python crecer tanto en su adopción porque reducen la cantidad de palabras que es necesario escribir para desarrollar código, lo cual ahorra tiempo y también disminuyen la complejidad.

# %% [markdown]
# ### Duck typing

# %%
class Serpiente():

    def __init__(self, nombre, largo):
        self.nombre = nombre
        self.largo = largo

    def __len__(self):
        return self.largo

    def saludar(self):
        return "ssssh"

mi_yarara = Serpiente('Yarará', 10)

# %% [markdown]
# <i> “If it walks like a duck, and it quacks like a duck, then it must be a duck.”</i>
#
# *Duck typing* significa que a diferencia de otros lenguajes, las funciones especiales no están definidas para una lista específica de clases y tipos, si no que se pueden usar para cualquier objeto que las implemente. Esto no es así para la mayoría de los lenguajes.

# %%
mi_str = "Hello World"
mi_list = [34, 54, 65, 78]
mi_dict = {"a": 123, "b": 456, "c": 789}

# %%
print(len(mi_str))
print(len(mi_list))
print(len(mi_dict))
print(len(mi_yarara))
# Out:
# 11
# 4
# 3
# 10

# %% [markdown]
# ### Monkey Patching

# %% [markdown]
# Guerrilla, gorilla, ¿monkey?... Este término viene de uno anterior, "guerrilla patching", que hace referencia a emparchar el código rápido y cuando es necesario.
#
# Se refiere a la posibilidad en Python de sobreescribir clases después de haberlas instanciado y por qué no, también la funcionalidad de los módulos.

# %%
mi_yarara.saludar()
# Out:
# 'ssssh'

# %%
def saludo_peligroso():
    return "SSSSSSSSSHHHH"

# %%
mi_yarara.saludar = saludo_peligroso

# %%
mi_yarara.saludar()
# Out:
# 'SSSSSSSSSHHHH'

# %% [markdown]
# Esto es especialmente útil cuando queremos sobre-escribir ligeramente módulos hechos por terceros (o por nosotros mismos en otro momento)

# %% [markdown]
# # Referencias y Recursos

# %% [markdown]
# *   https://docs.python.org/es/3/tutorial/index.html
# *   https://www.w3schools.com/python/default.asp
# *   https://github.com/institutohumai/cursos-python#intro-a-python

# %% [markdown]
# Tips:
#
# *   Dentro del notebook, con **Ctrl + Espacio** se despliega un menú de ayuda con los métodos y funciones del objeto o función que se tiene como foco.
