# %% [markdown]
# # Detección de Aves de la Selva Misionera con YOLOv5
#
#
#
# *Ejemplo de Transferencia de Aprendizaje en Redes Neuronales Artificiales*
#
#
# **CONTEXTO a tratar:**
#
# Suponga que un experto (https://www.youtube.com/c/SergioMoyaBioAudioVisual) le proporciona imágenes de especies poco frecuentes de avistar, son locales y por lo tanto no existen muchos registros.
#
# La idea es detectar si este tipo de aves aparecen dentro de los videos/fotografías tomadas por las cámaras trampa distribuidas en una reserva protegida. Se tienen registros de varios años, por lo tanto, muchos GB de información a procesar.
#
# La idea es obtener un modelo que permita facilitar esta ardua tarea.
#
# **Ejemplo:**
#
#
# ![image.png](data:image/png;base64,...)
#
#
# **POSIBLE SOLUCIÓN:**
#
# Utilizar una RNA, pero al disponer de pocas imágenes clasificadas con certeza, el proceso de entrenar una red desde cero y con las capacidades solicitadas... se torna inviable.
#
# Podemos utilizar una RNA ya entrenada para una tarea similar, agregar algunas capas para satisfacer nuestras necesidades, y entrenar estas últimas con nuestro dataset reducido.
#
#
# **Información adicional:**
#
#
# *   You Only Look Once (YOLO)
# *   https://docs.ultralytics.com/
# *   https://github.com/ultralytics/yolov5

# %% [markdown]
# ## (1) Dataset
#
# En este dataset hay imágenes a color de 8 tipos de aves misioneras. El tamaño de cada imagen es de 256x256 pixeles.
# A su vez, cada imagen presenta codificadas las etiquetas correspondientes para la identificación de las aves.

# %%
# Archivos pueden arrastrarse al área de trabajo o procesarse en local

# Version Online
# !wget -c --no-check-certificate "https://drive.google.com/uc?export=download&id=1Uw2zItbscfl8HkAHL7yBUwxz1agIu7Sl&confirm=t" -O Aves_processed.zip
# Out:
# --2023-12-01 21:39:16--  https://drive.google.com/uc?export=download&id=1Uw2zItbscfl8HkAHL7yBUwxz1agIu7Sl&confirm=t
# Resolving drive.google.com (drive.google.com)... 64.233.170.139, 64.233.170.101, 64.233.170.102, ...
# Connecting to drive.google.com (drive.google.com)|64.233.170.139|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-10-9c-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/1g6bhd1422ogsqfhcifglapl8da5ao4l/1701466725000/12225850433951268217/*/1Uw2zItbscfl8HkAHL7yBUwxz1agIu7Sl?e=download&uuid=093f3d27-9efe-45e7-b945-75324c355d29 [following]
# Warning: wildcards not supported in HTTP.
# --2023-12-01 21:39:19--  https://doc-10-9c-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/1g6bhd1422ogsqfhcifglapl8da5ao4l/1701466725000/12225850433951268217/*/1Uw2zItbscfl8HkAHL7yBUwxz1agIu7Sl?e=download&uuid=093f3d27-9efe-45e7-b945-75324c355d29
# Resolving doc-10-9c-docs.googleusercontent.com (doc-10-9c-docs.googleusercontent.com)... 74.125.68.132, 2404:6800:4003:c02::84
# Connecting to doc-10-9c-docs.googleusercontent.com (doc-10-9c-docs.googleusercontent.com)|74.125.68.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3403454 (3.2M) [application/x-zip-compressed]
# Saving to: ‘Aves_processed.zip’
#
# Aves_processed.zip  100%[===================>]   3.25M  --.-KB/s    in 0.02s
#
# 2023-12-01 21:39:20 (172 MB/s) - ‘Aves_processed.zip’ saved [3403454/3403454]

# %%
# !unzip -qq Aves_processed.zip

# %% [markdown]
# ### Formato utilizado por YOLO para los *bounding box*

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# En YOLOv5 es necesario generar un archivo texto por cada imagen que tenga objetos a detectar. Si la imagen se llama `<nombre_imagen>.jpg` y tiene objetos a detectar, debe crearse un archivo `<nombre_imagen>.txt` con $K$ filas, donde $K$ es el número de objetos a detectar que contiene la imagen `<nombre_imagen>.jpg`. Si en la imagen no hay objetos a detectar, entonces no se genera este archivo de texto.
#
# El *bounding box* se define como las esquinas **superior izquierda** `(x1,y1)` e **inferior derecha** `(x2,y2)`.
#
# Cada una de las $K$ filas de `<nombre_imagen>.txt` contiene 5 números separados por espacios. Los números corresponden a las siguientes variables:
#
# * `c` : número de la clase `c`, toma valores enteros consecutivos, comenzando por `0`.
#
# * `xn`: centro del *bounding box* normalizado en la dirección x, calculado como `xn = (x1+x2)/2/M`, donde `M` es el ancho en pixeles de la imagen.
#
# * `yn`: centro del *bounding box* normalizado en la dirección y, calculado como `yn = (y1+y2)/2/N`, donde `N` es el alto en pixeles de la imagen.
#
# * `wn`: ancho normalizado del *bounding box*, calculado como `wn = (x2-x1)/M`, donde `M` es el ancho en pixeles de la imagen.
#
# * `hn`: alto normalizado del *bounding box*, calculado como `hn = (y2-y1)/N`, donde `N` es el alto en pixeles de la imagen.

# %% [markdown]
# ## (2) Definición de Train/Val/Test data
#
# Es necesario dividir las imágenes de nuestro dataset en training, validation y testing. En este paso se copian las imágenes (con sus archivos de texto de los labels correspondientes) en los siguientes directorios.
# Esto se realiza de esta forma, porque YoLo espera una estructura similar.

# %% [markdown]
# ```
# data
#    |——————images
#    |        └——————train —— <trainimage01>.jpg
#    |        |               <trainimage02>.jpg
#    |        |                      :
#    |        └——————val   —— <valimage01>.jpg
#    |        |               <valimage02>.jpg
#    |        |                      :
#    |        └——————test —— <testimage01>.jpg
#    |        |               <testimage02>.jpg
#    |        |                      :
#    └——————labels
#    |        └——————train —— <trainimage01>.txt
#    |        |               <trainimage02>.txt
#    |        |                      :
#    |        └——————val   —— <valimage01>.txt
#    |        |               <valimage02>.txt
#    |        |                      :
#    |        └——————test —— <testimage01>.txt
#    |        |               <testimage02>.txt
#    |        |                      :
# ```

# %%
# !mkdir data
# !mkdir data/images
# !mkdir data/images/train
# !mkdir data/images/val
# !mkdir data/images/test
# !mkdir data/labels
# !mkdir data/labels/train
# !mkdir data/labels/val
# !mkdir data/labels/test

# %%
from tqdm.auto import tqdm
import os, fnmatch

def dirfiles(img_path,img_ext):
    img_names = fnmatch.filter(sorted(os.listdir(img_path)),img_ext)
    return img_names

# %%
import numpy as np
SEED = 777
np.random.seed(SEED)


p_train = 0.70  # 70% del total de los datos son training
p_val   = 0.10  # 10% de los datos de training son de validación


d = dirfiles('images/','*.jpg')
m = len(d) # número de imagenes

nt = round(p_train*m)
nv = round(p_val*nt)

ii = np.vstack([np.zeros((nt-nv,1)),np.ones((nv,1)),2*np.ones((m-nt,1))])
np.random.shuffle(ii) # Aleatorio


target = ['train','val','test']

for i in tqdm(range(m)):
  fname            = d[i]
  tname            = fname[:-3]+'txt'
  ti               = target[int(ii[i])]
  source_file      = 'images/'+fname
  destination_file = 'data/images/'+ti
  os.system('cp ' + source_file + ' ' + destination_file)
  source_file      = 'labels/'+tname
  destination_file = 'data/labels/'+ti
  os.system('cp ' + source_file + ' ' + destination_file)

print('Training: ', nt-nv)
print('     Val: ', nv)
print(' Testing: ',m-nt)
# Out:
#   0%|          | 0/144 [00:00<?, ?it/s]
# Training:  91
#      Val:  10
#  Testing:  43

# %% [markdown]
# ## (3) Definición de archivo YAML
#
# Es necesario definir el archivo `data/data.yaml` que contiene la información de:
#
# * los directorios de training, validation y testing
#
# * el nombre de las clases
#
# * el número de clases

# %%
# Nueva version de YOLO, salió hace poquito. A veces cambia la estructura base. Puede que en un futuro no funcione como está
PATH_ROOT = 'data'
PATH_TRAIN = 'images/train'
PATH_VAL   = 'images/val'
PATH_TEST  = 'images/test'
N_CLASSES  = 8 # Comienza en 0 las class labels. Rango entre 0 y nc-1.

class_names = ['Aguila Viuda', 'Aranero Coronado Chico', 'Bailarin Azul', 'Bailarin Naranja', 'Batara Pintado', 'Cardenal Comun', 'Carpintero Garganta Estriada', 'Picaflor Cronova Violacea']

f = open('data/data.yaml','w+')

f.write('path: ../'+PATH_ROOT+'\n')
f.write('train: '+PATH_TRAIN+'\n')
f.write('val: '+PATH_VAL+'\n')
f.write('test: '+PATH_TEST+'\n')
f.write('nc: '+str(N_CLASSES)+'\n')
f.write('names: '+str(class_names)+'\n')

f.close()

# %%
# !cat data/data.yaml
# Out:
# path: ../data
# train: images/train
# val: images/val
# test: images/test
# nc: 8
# names: ['Aguila Viuda', 'Aranero Coronado Chico', 'Bailarin Azul', 'Bailarin Naranja', 'Batara Pintado', 'Cardenal Comun', 'Carpintero Garganta Estriada', 'Picaflor Cronova Violacea']

# %% [markdown]
# # YOLOv5
#
# Una vez definida la base de datos, los subsets de training, testing y validación, con las anotaciones de los objetos a detectar en el formato requerido por YOLOv5 se procede a entrenar. Para esto necesitamos instalar la librería [YOLOv5](https://github.com/ultralytics/yolov5) desarrollada por Ultralytics.

# %% [markdown]
# ## Instalación

# %%
# !pip install -qr https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 4.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 83.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 646.6/646.6 kB 53.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.0 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# imageio 2.31.6 requires pillow<10.1.0,>=8.3.2, but you have pillow 10.1.0 which is incompatible.

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16078, done.
# remote: Counting objects: 100% (22/22), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 16078 (delta 6), reused 9 (delta 1), pack-reused 16056
# Receiving objects: 100% (16078/16078), 14.72 MiB | 17.03 MiB/s, done.
# Resolving deltas: 100% (11038/11038), done.

# %%
# !pip install -qr yolov5/requirements.txt  # install dependencies (ignore errors)

# %%
pwd
# Out:
# '/content'

# %%
# %cd yolov5
# Out:
# /content/yolov5

# %% [markdown]
# ## Definiciones

# %%
YOLO_MODEL     = 'yolov5m' # puede ser yolov5n yolov5s yolov5m, yolov5l, yolov5x. Hay diferentes tamaños disponibles.
EPOCHS         = 200
CFG            = YOLO_MODEL+'.yaml'
TRAIN_WEIGHTS  = YOLO_MODEL+'.pt'  # o pesos de otro modelo propio pre-entrenado
BATCH          = 8 # original 8
IMG_SIZE       = 256
YAMLFILE       = '../data/data.yaml'

# %% [markdown]
# ## Entrenamiento

# %%
# !python train.py --img {IMG_SIZE} --batch {BATCH} --epochs {EPOCHS} --data {YAMLFILE} --cfg {CFG} --weights {TRAIN_WEIGHTS} --nosave --cache
# Out:
# 2023-12-01 21:54:40.375910: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-01 21:54:40.375974: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-01 21:54:40.376014: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# train: weights=yolov5m.pt, cfg=yolov5m.yaml, data=../data/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=200, batch_size=8, imgsz=256, rect=False, resume=False, nosave=True, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-247-g3f02fde Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100% 755k/755k [00:00<00:00, 134MB/s]
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5m.pt to yolov5m.pt...
# 100% 40.8M/40.8M [00:00<00:00, 345MB/s]
#
# Overriding model.yaml nc=80 with nc=8
#
#                  from  n    params  module                                  arguments
#   0                -1  1      5280  models.common.Conv                      [3, 48, 6, 2, 2]
#   1                -1  1     41664  models.common.Conv                      [48, 96, 3, 2]
#   2                -1  2     65280  models.common.C3                        [96, 96, 2]
#   3                -1  1    166272  models.common.Conv                      [96, 192, 3, 2]
#   4                -1  4    444672  models.common.C3                        [192, 192, 4]
#   5                -1  1    664320  models.common.Conv                      [192, 384, 3, 2]
#   6                -1  6   2512896  models.common.C3                        [384, 384, 6]
#   7                -1  1   2655744  models.common.Conv                      [384, 768, 3, 2]
#   8                -1  2   4134912  models.common.C3                        [768, 768, 2]
#   9                -1  1   1476864  models.common.SPPF                      [768, 768, 5]
#  10                -1  1    295680  models.common.Conv                      [768, 384, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  2   1182720  models.common.C3                        [768, 384, 2, False]
#  14                -1  1     74112  models.common.Conv                      [384, 192, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  2    296448  models.common.C3                        [384, 192, 2, False]
#  18                -1  1    332160  models.common.Conv                      [192, 192, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  2   1035264  models.common.C3                        [384, 384, 2, False]
#  21                -1  1   1327872  models.common.Conv                      [384, 384, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  2   4134912  models.common.C3                        [768, 768, 2, False]
#  24      [17, 20, 23]  1     52533  models.yolo.Detect                      [8, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [192, 384, 768]]
# YOLOv5m summary: 291 layers, 20899605 parameters, 20899605 gradients, 48.3 GFLOPs
#
# Transferred 474/481 items from yolov5m.pt
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 79 weight(decay=0.0), 82 weight(decay=0.0005), 82 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# train: Scanning /content/data/labels/train... 89 images, 2 backgrounds, 0 corrupt: 100% 91/91 [00:00<00:00, 1490.75it/s]
# train: New cache created: /content/data/labels/train.cache
# train: Caching images (0.0GB ram): 100% 91/91 [00:00<00:00, 790.20it/s]
# val: Scanning /content/data/labels/val... 10 images, 0 backgrounds, 0 corrupt: 100% 10/10 [00:00<00:00, 242.00it/s]
# val: New cache created: /content/data/labels/val.cache
# val: Caching images (0.0GB ram): 100% 10/10 [00:00<00:00, 457.54it/s]
#
# AutoAnchor: 5.51 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/exp/labels.jpg...
# Image sizes 256 train, 256 val
# Using 2 dataloader workers
# Logging results to runs/train/exp
# Starting training for 200 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       0/199      1.05G     0.1112    0.01363     0.0624          7        256: 100% 12/12 [00:05<00:00,  2.17it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.28s/it]
#                    all         10         10    0.00256        0.5    0.00651    0.00171
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       1/199      1.06G     0.0972    0.01459    0.06128          7        256: 100% 12/12 [00:01<00:00,  9.13it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 12.39it/s]
#                    all         10         10    0.00311      0.583    0.00495    0.00119
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       2/199      1.06G    0.08713    0.01889    0.06144          5        256: 100% 12/12 [00:01<00:00,  9.09it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  8.43it/s]
#                    all         10         10    0.00413      0.917     0.0179    0.00463
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       3/199      1.06G     0.0823     0.0186     0.0592          8        256: 100% 12/12 [00:01<00:00,  7.47it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  7.33it/s]
#                    all         10         10    0.00487          1      0.102      0.045
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       4/199      1.06G    0.07254    0.02055     0.0571          5        256: 100% 12/12 [00:01<00:00,  7.33it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  7.49it/s]
#                    all         10         10    0.00474      0.833      0.115     0.0586
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       5/199      1.06G    0.07016     0.0222    0.05555         10        256: 100% 12/12 [00:01<00:00,  9.06it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 10.71it/s]
#                    all         10         10    0.00443      0.917     0.0941     0.0492
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       6/199      1.06G    0.06571     0.0212    0.05504          5        256: 100% 12/12 [00:01<00:00, 10.73it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 11.51it/s]
#                    all         10         10     0.0241      0.306      0.131     0.0539
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       7/199      1.06G    0.06792    0.01755    0.05412          4        256: 100% 12/12 [00:01<00:00, 11.13it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 10.62it/s]
#                    all         10         10     0.0316      0.917      0.154      0.063
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       8/199      1.06G    0.06561    0.01896    0.05387          5        256: 100% 12/12 [00:01<00:00, 10.64it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 10.42it/s]
#                    all         10         10      0.106      0.389      0.232     0.0953
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       9/199      1.06G    0.06998    0.01831    0.05063          5        256: 100% 12/12 [00:01<00:00, 10.70it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 10.80it/s]
#                    all         10         10      0.709      0.167      0.508      0.204
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      10/199      1.06G    0.06209    0.01804    0.05042          5        256: 100% 12/12 [00:01<00:00, 10.60it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 10.36it/s]
#                    all         10         10      0.479      0.528      0.558      0.226
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      11/199      1.06G     0.0626    0.01765    0.05048          6        256: 100% 12/12 [00:01<00:00, 10.59it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 10.39it/s]
#                    all         10         10       0.32      0.583      0.615      0.274
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      12/199      1.06G    0.05728    0.01962    0.05001          8        256: 100% 12/12 [00:01<00:00, 10.67it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 10.69it/s]
#                    all         10         10      0.456      0.417      0.482      0.211
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      13/199      1.06G    0.06049    0.01717    0.04905          9        256: 100% 12/12 [00:01<00:00,  8.21it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  7.98it/s]
#                    all         10         10      0.364      0.505      0.572      0.283
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      14/199      1.06G    0.05371    0.01925    0.05026          6        256: 100% 12/12 [00:01<00:00,  7.47it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  6.65it/s]
#                    all         10         10      0.384      0.655      0.471      0.263
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      15/199      1.06G    0.05818    0.01754    0.04792          9        256: 100% 12/12 [00:01<00:00,  7.50it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  8.15it/s]
#                    all         10         10        0.4       0.65      0.516       0.26
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      16/199      1.06G    0.05305    0.01723    0.04866          8        256: 100% 12/12 [00:01<00:00, 10.40it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  9.86it/s]
#                    all         10         10       0.27      0.417      0.393       0.22
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      17/199      1.06G     0.0584    0.01593    0.04832          5        256: 100% 12/12 [00:01<00:00, 10.57it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 10.16it/s]
#                    all         10         10      0.298      0.814      0.448        0.2
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      18/199      1.06G    0.04902    0.01567    0.04835          3        256: 100% 12/12 [00:01<00:00, 10.65it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 10.81it/s]
#                    all         10         10       0.48      0.583      0.433      0.207
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      19/199      1.06G    0.05685     0.0144    0.04654          5        256: 100% 12/12 [00:01<00:00, 10.84it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 11.01it/s]
#                    all         10         10      0.466      0.333      0.466      0.252
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      20/199      1.06G    0.05043    0.01612    0.04446          6        256: 100% 12/12 [00:01<00:00, 10.22it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  9.45it/s]
#                    all         10         10      0.873      0.222      0.422      0.218
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      21/199      1.06G    0.04905    0.01471    0.04514          5        256: 100% 12/12 [00:01<00:00, 10.85it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 10.72it/s]
#                    all         10         10      0.152      0.587      0.461       0.33
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      22/199      1.06G    0.04459    0.01612    0.04491          5        256: 100% 12/12 [00:01<00:00, 10.39it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 10.36it/s]
#                    all         10         10      0.853      0.222      0.475      0.338
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      23/199      1.06G    0.05246    0.01377    0.04387          6        256: 100% 12/12 [00:01<00:00, 10.36it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  7.45it/s]
#                    all         10         10      0.437        0.5      0.567      0.378
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      24/199      1.06G    0.04312    0.01404    0.04363          7        256: 100% 12/12 [00:01<00:00,  7.43it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  7.84it/s]
#                    all         10         10      0.461        0.5      0.618      0.425
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      25/199      1.06G    0.05223    0.01237    0.04237          4        256: 100% 12/12 [00:01<00:00,  7.33it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  7.60it/s]
#                    all         10         10      0.468        0.5      0.665      0.331
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      26/199      1.06G    0.04521     0.0131     0.0422          3        256: 100% 12/12 [00:01<00:00,  8.72it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 11.23it/s]
#                    all         10         10      0.374      0.583      0.719      0.368
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      27/199      1.06G    0.04736    0.01324     0.0432          6        256: 100% 12/12 [00:01<00:00, 10.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 11.21it/s]
#                    all         10         10      0.649      0.583      0.717       0.35
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      28/199      1.06G    0.03869    0.01256    0.04146          3        256: 100% 12/12 [00:01<00:00, 10.27it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 10.73it/s]
#                    all         10         10      0.741      0.583      0.745       0.37
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      29/199      1.06G    0.04437    0.01329    0.04204          8        256: 100% 12/12 [00:01<00:00, 10.70it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 11.14it/s]
#                    all         10         10      0.687      0.583      0.724      0.477
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      30/199      1.06G    0.04098    0.01226     0.0427          7        256: 100% 12/12 [00:01<00:00, 10.34it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 11.28it/s]
#                    all         10         10      0.644      0.528       0.67      0.483
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      31/199      1.06G    0.04604    0.01207    0.03991          7        256: 100% 12/12 [00:01<00:00, 10.48it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 11.61it/s]
#                    all         10         10      0.635      0.546      0.682      0.383
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      32/199      1.06G    0.03866    0.01248    0.04049          6        256: 100% 12/12 [00:01<00:00, 10.53it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 11.13it/s]
#                    all         10         10      0.727      0.628      0.725      0.421
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      33/199      1.06G    0.04316    0.01175      0.039          9        256: 100% 12/12 [00:01<00:00, 10.51it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 11.31it/s]
#                    all         10         10       0.75      0.583      0.776      0.515
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      34/199      1.06G    0.04113    0.01069    0.04105          4        256: 100% 12/12 [00:01<00:00,  7.61it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  7.34it/s]
#                    all         10         10      0.633      0.642      0.679      0.352
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      35/199      1.06G    0.04401    0.01149    0.03649          6        256: 100% 12/12 [00:01<00:00,  7.42it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  8.22it/s]
#                    all         10         10      0.756      0.653      0.715      0.441
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      36/199      1.06G    0.03891    0.01214    0.03972          7        256: 100% 12/12 [00:01<00:00,  7.52it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 12.01it/s]
#                    all         10         10      0.777      0.619        0.7      0.433
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      37/199      1.06G    0.04316    0.01082    0.03639          5        256: 100% 12/12 [00:01<00:00, 10.71it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 11.42it/s]
#                    all         10         10      0.867      0.636      0.705      0.383
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      38/199      1.06G    0.04153    0.01158    0.03592          5        256: 100% 12/12 [00:01<00:00, 10.66it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 10.78it/s]
#                    all         10         10      0.749      0.613      0.695      0.397
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      39/199      1.06G    0.04096    0.01114    0.03498          6        256: 100% 12/12 [00:01<00:00, 10.75it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 10.33it/s]
#                    all         10         10      0.782       0.62      0.707      0.423
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      40/199      1.06G    0.03804    0.01185     0.0379          7        256: 100% 12/12 [00:01<00:00, 10.44it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 10.73it/s]
#                    all         10         10      0.752      0.636      0.718      0.427
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      41/199      1.06G     0.0419    0.01112    0.03469          7        256: 100% 12/12 [00:01<00:00, 10.86it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 11.04it/s]
#                    all         10         10      0.785      0.641      0.745       0.39
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      42/199      1.06G    0.03374    0.01121    0.03516          5        256: 100% 12/12 [00:01<00:00, 10.50it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 11.27it/s]
#                    all         10         10      0.843      0.637      0.781      0.516
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      43/199      1.06G    0.04057    0.01075    0.03438          5        256: 100% 12/12 [00:01<00:00, 10.95it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 10.96it/s]
#                    all         10         10      0.887      0.637      0.786      0.538
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      44/199      1.06G    0.03422    0.01001    0.03408          2        256: 100% 12/12 [00:01<00:00,  9.75it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  8.34it/s]
#                    all         10         10      0.785      0.627      0.742      0.511
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      45/199      1.06G    0.03962   0.009786    0.03031          4        256: 100% 12/12 [00:01<00:00,  7.79it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  8.27it/s]
#                    all         10         10      0.895      0.632      0.744      0.462
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      46/199      1.06G    0.03761    0.01026    0.03142          8        256: 100% 12/12 [00:01<00:00,  6.66it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  8.08it/s]
#                    all         10         10      0.884      0.636      0.731      0.339
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      47/199      1.06G    0.04237    0.01107    0.03219          8        256: 100% 12/12 [00:01<00:00,  8.99it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 10.68it/s]
#                    all         10         10      0.801      0.637      0.715      0.471
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      48/199      1.06G    0.03614    0.01128    0.03094          8        256: 100% 12/12 [00:01<00:00, 10.66it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 11.70it/s]
#                    all         10         10      0.795      0.632      0.671      0.452
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      49/199      1.06G    0.03893    0.01082    0.03137          6        256: 100% 12/12 [00:01<00:00, 10.70it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 11.20it/s]
#                    all         10         10      0.932      0.633      0.756      0.522
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      50/199      1.06G    0.03686    0.01071    0.03097          5        256: 100% 12/12 [00:01<00:00, 10.39it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 11.50it/s]
#                    all         10         10      0.822      0.583      0.766      0.548
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      51/199      1.06G    0.03793    0.01033    0.03053          7        256: 100% 12/12 [00:01<00:00, 10.89it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  9.90it/s]
#                    all         10         10       0.91       0.63      0.793       0.61
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      52/199      1.06G    0.03414   0.009245    0.02902          3        256: 100% 12/12 [00:01<00:00, 10.66it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 11.81it/s]
#                    all         10         10      0.624      0.748      0.798      0.502
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      53/199      1.06G    0.03515    0.00988    0.02832          7        256: 100% 12/12 [00:01<00:00, 10.92it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 11.25it/s]
#                    all         10         10      0.575      0.749      0.796      0.634
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      54/199      1.06G    0.03301   0.009301    0.02994          5        256: 100% 12/12 [00:01<00:00, 10.66it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 11.82it/s]
#                    all         10         10      0.924      0.612      0.798      0.492
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      55/199      1.06G    0.03694    0.01011    0.02741          7        256: 100% 12/12 [00:01<00:00,  8.46it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  7.13it/s]
#                    all         10         10      0.926      0.615      0.803      0.568
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      56/199      1.06G    0.03072    0.00931    0.03027          5        256: 100% 12/12 [00:01<00:00,  7.47it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  7.19it/s]
#                    all         10         10       0.89      0.607      0.803      0.581
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      57/199      1.06G    0.03709   0.009881    0.02431          8        256: 100% 12/12 [00:01<00:00,  7.78it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  7.60it/s]
#                    all         10         10      0.969      0.596      0.821      0.595
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      58/199      1.06G    0.03709     0.0094    0.02683         10        256: 100% 12/12 [00:01<00:00, 10.40it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 10.23it/s]
#                    all         10         10      0.928      0.594      0.829      0.673
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      59/199      1.06G    0.03528    0.01024    0.02621          4        256: 100% 12/12 [00:01<00:00, 10.59it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 11.03it/s]
#                    all         10         10      0.908      0.583      0.807      0.634
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      60/199      1.06G    0.03555    0.01016    0.02331          3        256: 100% 12/12 [00:01<00:00, 10.68it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 11.29it/s]
#                    all         10         10      0.454       0.75      0.835      0.619
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      61/199      1.06G     0.0349   0.009754    0.02388          7        256: 100% 12/12 [00:01<00:00, 10.86it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 11.69it/s]
#                    all         10         10      0.638      0.791      0.871      0.656
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      62/199      1.06G    0.03417    0.01051    0.02435          7        256: 100% 12/12 [00:01<00:00, 10.70it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 10.79it/s]
#                    all         10         10      0.486       0.75      0.829      0.665
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      63/199      1.06G    0.03663    0.01035    0.02308          9        256: 100% 12/12 [00:01<00:00, 10.58it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 11.75it/s]
#                    all         10         10      0.535       0.75      0.785      0.551
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      64/199      1.06G    0.03503   0.008874    0.02155          5        256: 100% 12/12 [00:01<00:00, 10.30it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 10.26it/s]
#                    all         10         10      0.522       0.75      0.807       0.62
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      65/199      1.06G    0.03466    0.01039    0.02195          9        256: 100% 12/12 [00:01<00:00, 10.77it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  9.55it/s]
#                    all         10         10      0.554       0.75      0.835      0.587
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      66/199      1.06G    0.03109   0.009253    0.02196          5        256: 100% 12/12 [00:01<00:00,  7.03it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  7.45it/s]
#                    all         10         10      0.961      0.606      0.835      0.535
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      67/199      1.06G      0.035   0.009319    0.02182          4        256: 100% 12/12 [00:01<00:00,  7.51it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  8.96it/s]
#                    all         10         10      0.579       0.75      0.815      0.585
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      68/199      1.06G    0.03122    0.01036    0.02134          4        256: 100% 12/12 [00:01<00:00,  8.42it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 10.68it/s]
#                    all         10         10      0.623      0.797      0.871      0.593
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      69/199      1.06G     0.0345   0.009738    0.02311          4        256: 100% 12/12 [00:01<00:00, 10.74it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 11.40it/s]
#                    all         10         10      0.545      0.807      0.857       0.63
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      70/199      1.06G    0.03191   0.009569     0.0192          7        256: 100% 12/12 [00:01<00:00, 10.85it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 11.50it/s]
#                    all         10         10      0.857      0.664      0.857      0.618
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      71/199      1.06G    0.03382   0.009041    0.01997          4        256: 100% 12/12 [00:01<00:00, 10.80it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 11.02it/s]
#                    all         10         10      0.604      0.812      0.884      0.706
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      72/199      1.06G    0.03176     0.0107    0.01763          6        256: 100% 12/12 [00:01<00:00, 10.21it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 10.51it/s]
#                    all         10         10      0.535      0.822      0.843      0.607
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      73/199      1.06G    0.03852   0.009862    0.01809          6        256: 100% 12/12 [00:01<00:00, 10.28it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 10.80it/s]
#                    all         10         10      0.619       0.81      0.871      0.645
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      74/199      1.06G    0.03108   0.008934    0.01824          6        256: 100% 12/12 [00:01<00:00, 10.19it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 10.76it/s]
#                    all         10         10      0.663      0.992      0.912      0.666
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      75/199      1.06G    0.03258   0.009806    0.01721         10        256: 100% 12/12 [00:01<00:00, 10.53it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 10.71it/s]
#                    all         10         10       0.71          1      0.912      0.698
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      76/199      1.06G    0.03294   0.008772    0.01703          3        256: 100% 12/12 [00:01<00:00,  8.38it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  8.26it/s]
#                    all         10         10      0.642          1      0.912      0.736
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      77/199      1.06G    0.03438   0.009119    0.01657          7        256: 100% 12/12 [00:01<00:00,  7.35it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  7.57it/s]
#                    all         10         10      0.632          1      0.912      0.723
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      78/199      1.06G    0.02963   0.009716    0.01472          3        256: 100% 12/12 [00:01<00:00,  6.57it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  6.22it/s]
#                    all         10         10      0.597          1      0.912      0.656
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      79/199      1.06G    0.03511   0.008586    0.01652          5        256: 100% 12/12 [00:01<00:00,  8.53it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 11.25it/s]
#                    all         10         10      0.618          1      0.912      0.766
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      80/199      1.06G    0.03232   0.009038    0.01759          5        256: 100% 12/12 [00:01<00:00, 10.40it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 11.93it/s]
#                    all         10         10      0.576          1      0.995      0.709
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      81/199      1.06G    0.03219   0.007977     0.0164          3        256: 100% 12/12 [00:01<00:00, 10.88it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 10.47it/s]
#                    all         10         10      0.614          1      0.995      0.795
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      82/199      1.06G    0.03069   0.008722    0.01795          7        256: 100% 12/12 [00:01<00:00, 10.31it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 11.62it/s]
#                    all         10         10      0.633      0.999      0.995      0.788
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      83/199      1.06G    0.03089    0.00838    0.01693          1        256: 100% 12/12 [00:01<00:00, 10.50it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 10.39it/s]
#                    all         10         10      0.677      0.985      0.995      0.725
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      84/199      1.06G    0.02954   0.009441    0.01543          9        256: 100% 12/12 [00:01<00:00, 10.33it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 11.60it/s]
#                    all         10         10      0.741      0.986      0.995      0.716
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      85/199      1.06G    0.03061   0.008687    0.01463          3        256: 100% 12/12 [00:01<00:00, 10.78it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 11.56it/s]
#                    all         10         10      0.699      0.991      0.995      0.713
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      86/199      1.06G    0.03004   0.009585    0.01409          4        256: 100% 12/12 [00:01<00:00, 10.25it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 11.46it/s]
#                    all         10         10      0.777      0.987      0.995      0.716
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      87/199      1.06G    0.03298   0.007588    0.01317          9        256: 100% 12/12 [00:01<00:00,  7.71it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  8.56it/s]
#                    all         10         10      0.811      0.977      0.995      0.726
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      88/199      1.06G    0.03373   0.009586    0.01568          4        256: 100% 12/12 [00:01<00:00,  7.42it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  7.84it/s]
#                    all         10         10      0.843      0.967      0.995      0.705
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      89/199      1.06G     0.0305   0.008646    0.01176          5        256: 100% 12/12 [00:01<00:00,  7.76it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 10.74it/s]
#                    all         10         10      0.849       0.96      0.995      0.696
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      90/199      1.06G    0.03121   0.008233    0.01345          4        256: 100% 12/12 [00:01<00:00, 10.38it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 11.14it/s]
#                    all         10         10      0.854      0.953      0.995      0.755
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      91/199      1.06G    0.03139   0.008537     0.0137          5        256: 100% 12/12 [00:01<00:00, 10.57it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 11.07it/s]
#                    all         10         10      0.863      0.948      0.995      0.659
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      92/199      1.06G    0.03177    0.00986     0.0117          6        256: 100% 12/12 [00:01<00:00, 10.23it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 11.29it/s]
#                    all         10         10      0.859      0.959      0.995      0.766
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      93/199      1.06G    0.03033   0.009213    0.01095         11        256: 100% 12/12 [00:01<00:00, 10.63it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  9.66it/s]
#                    all         10         10      0.862      0.964      0.995      0.737
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      94/199      1.06G    0.02969   0.007887     0.0121          5        256: 100% 12/12 [00:01<00:00, 10.62it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 11.35it/s]
#                    all         10         10       0.82      0.973      0.995       0.74
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      95/199      1.06G     0.0302   0.009669    0.01166          6        256: 100% 12/12 [00:01<00:00, 10.65it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 10.85it/s]
#                    all         10         10      0.848      0.996      0.995      0.759
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      96/199      1.06G    0.03065   0.009063    0.01232          4        256: 100% 12/12 [00:01<00:00, 10.58it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 11.77it/s]
#                    all         10         10      0.833          1      0.995      0.724
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      97/199      1.06G    0.02859    0.00781    0.01024          6        256: 100% 12/12 [00:01<00:00, 10.34it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  7.67it/s]
#                    all         10         10      0.699          1      0.967      0.715
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      98/199      1.06G    0.02796   0.008318   0.009915          3        256: 100% 12/12 [00:01<00:00,  7.43it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  8.84it/s]
#                    all         10         10      0.768          1      0.995      0.636
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      99/199      1.06G    0.03029   0.008075    0.01243          2        256: 100% 12/12 [00:01<00:00,  7.78it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  8.24it/s]
#                    all         10         10      0.835          1      0.995       0.69
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     100/199      1.06G    0.02869   0.009082    0.01225          4        256: 100% 12/12 [00:01<00:00,  8.50it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 10.76it/s]
#                    all         10         10      0.865          1      0.995      0.714
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     101/199      1.06G    0.02781   0.008049    0.01038          5        256: 100% 12/12 [00:01<00:00, 10.72it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 10.32it/s]
#                    all         10         10      0.864          1      0.995      0.704
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
# ...
#     161/199      1.06G    0.02211   0.007962   0.005011          6        256: 100% 12/12 [00:01<00:00, 10.73it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  7.56it/s]
#                    all         10         10      0.909          1      0.995      0.745
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     162/199      1.06G    0.02142   0.007826   0.006721          7        256: 100% 12/12 [00:01<00:00,  7.35it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  8.38it/s]
#                    all         10         10      0.906          1      0.995      0.798
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     163/199      1.06G    0.02243   0.007795   0.006305          4        256: 100% 12/12 [00:01<00:00,  7.52it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  8.72it/s]
#                    all         10         10      0.902          1      0.995      0.807
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     164/199      1.06G     0.0197   0.007715   0.005676          7        256: 100% 12/12 [00:01<00:00,  8.49it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 11.64it/s]
#                    all         10         10      0.901          1      0.995       0.84
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     165/199      1.06G    0.01979   0.006764   0.004607          5        256: 100% 12/12 [00:01<00:00, 10.98it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 10.70it/s]
#                    all         10         10      0.898          1      0.995      0.837
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     166/199      1.06G     0.0188   0.007362   0.006386          7        256: 100% 12/12 [00:01<00:00, 10.66it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  9.17it/s]
#                    all         10         10      0.896          1      0.995      0.838
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     167/199      1.06G    0.01869   0.007719   0.004068          7        256: 100% 12/12 [00:01<00:00, 10.87it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 11.62it/s]
#                    all         10         10      0.892          1      0.995      0.798
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     168/199      1.06G    0.01912   0.007433    0.00592          7        256: 100% 12/12 [00:01<00:00, 10.69it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 11.11it/s]
#                    all         10         10      0.896          1      0.995      0.832
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     169/199      1.06G    0.01922   0.006962   0.004775          5        256: 100% 12/12 [00:01<00:00, 10.96it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 11.41it/s]
#                    all         10         10      0.898          1      0.995      0.837
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     170/199      1.06G    0.01945   0.006587   0.004237          8        256: 100% 12/12 [00:01<00:00, 10.56it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 11.76it/s]
#                    all         10         10      0.902          1      0.995      0.854
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     171/199      1.06G    0.01898   0.006947   0.004736          3        256: 100% 12/12 [00:01<00:00, 10.53it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 11.41it/s]
#                    all         10         10      0.904          1      0.995      0.848
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     172/199      1.06G    0.01863   0.006675   0.004508          4        256: 100% 12/12 [00:01<00:00,  8.71it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  7.40it/s]
#                    all         10         10      0.909          1      0.995      0.803
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     173/199      1.06G    0.02109    0.00682   0.005419          6        256: 100% 12/12 [00:01<00:00,  7.12it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  8.26it/s]
#                    all         10         10      0.911          1      0.995      0.829
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     174/199      1.06G    0.01732   0.007013   0.004284          3        256: 100% 12/12 [00:01<00:00,  7.15it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  8.48it/s]
#                    all         10         10       0.91          1      0.995      0.821
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     175/199      1.06G    0.02058   0.007024   0.006036          7        256: 100% 12/12 [00:01<00:00,  9.51it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 11.68it/s]
#                    all         10         10      0.913          1      0.995      0.807
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     176/199      1.06G     0.0184   0.006307   0.004122          5        256: 100% 12/12 [00:01<00:00, 10.32it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 10.74it/s]
#                    all         10         10      0.917          1      0.995      0.832
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     177/199      1.06G    0.01821   0.008094   0.005568          8        256: 100% 12/12 [00:01<00:00, 10.16it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 10.80it/s]
#                    all         10         10       0.91          1      0.995      0.813
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     178/199      1.06G    0.01899    0.00725   0.005046          6        256: 100% 12/12 [00:01<00:00, 10.26it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 11.04it/s]
#                    all         10         10      0.905          1      0.995      0.816
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     179/199      1.06G    0.01735   0.006655   0.006357          6        256: 100% 12/12 [00:01<00:00, 10.30it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 10.32it/s]
#                    all         10         10      0.903          1      0.995      0.824
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     180/199      1.06G    0.01727   0.006423   0.004263          6        256: 100% 12/12 [00:01<00:00, 10.48it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  9.45it/s]
#                    all         10         10      0.907          1      0.995      0.854
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     181/199      1.06G     0.0183   0.006767   0.005008          8        256: 100% 12/12 [00:01<00:00, 10.78it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  9.27it/s]
#                    all         10         10      0.908          1      0.995      0.837
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     182/199      1.06G    0.01904   0.007473   0.004835          4        256: 100% 12/12 [00:01<00:00, 10.62it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 10.56it/s]
#                    all         10         10      0.903          1      0.995      0.837
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     183/199      1.06G    0.01845   0.006546   0.004926          5        256: 100% 12/12 [00:01<00:00,  8.21it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  8.11it/s]
#                    all         10         10        0.9          1      0.995      0.849
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     184/199      1.06G    0.01835   0.007145   0.005146          8        256: 100% 12/12 [00:01<00:00,  7.19it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  8.27it/s]
#                    all         10         10      0.902          1      0.995      0.856
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     185/199      1.06G    0.01877   0.006349   0.006025          5        256: 100% 12/12 [00:01<00:00,  8.05it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 11.53it/s]
#                    all         10         10      0.893          1      0.995      0.838
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     186/199      1.06G    0.01698   0.006517   0.004639          4        256: 100% 12/12 [00:01<00:00, 10.35it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 11.67it/s]
#                    all         10         10      0.889          1      0.995       0.84
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     187/199      1.06G    0.01802   0.006915   0.004046          3        256: 100% 12/12 [00:01<00:00, 10.37it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 11.49it/s]
#                    all         10         10      0.887          1      0.995       0.84
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     188/199      1.06G    0.01686   0.006579    0.00515          2        256: 100% 12/12 [00:01<00:00, 10.18it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 11.90it/s]
#                    all         10         10      0.887          1      0.995      0.829
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     189/199      1.06G    0.01997   0.007322   0.006223          5        256: 100% 12/12 [00:01<00:00, 10.77it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 10.89it/s]
#                    all         10         10      0.888          1      0.995      0.829
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     190/199      1.06G    0.01743   0.006299   0.004439          4        256: 100% 12/12 [00:01<00:00, 10.59it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 10.99it/s]
#                    all         10         10      0.894          1      0.995      0.832
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     191/199      1.06G    0.01795   0.006925   0.004712          4        256: 100% 12/12 [00:01<00:00, 10.73it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 11.15it/s]
#                    all         10         10      0.894          1      0.995      0.846
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     192/199      1.06G      0.017   0.007466   0.003847          6        256: 100% 12/12 [00:01<00:00, 10.36it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 11.27it/s]
#                    all         10         10      0.894          1      0.995      0.821
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     193/199      1.06G    0.01603   0.005985   0.005752          5        256: 100% 12/12 [00:01<00:00,  9.43it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  8.29it/s]
#                    all         10         10      0.896          1      0.995      0.821
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     194/199      1.06G     0.0159   0.006977   0.002652          7        256: 100% 12/12 [00:01<00:00,  7.34it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  7.51it/s]
#                    all         10         10      0.906          1      0.995      0.823
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     195/199      1.06G    0.01681   0.006686   0.004468          8        256: 100% 12/12 [00:01<00:00,  7.60it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  8.37it/s]
#                    all         10         10      0.909          1      0.995      0.831
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     196/199      1.06G    0.01525   0.006455   0.003457          4        256: 100% 12/12 [00:01<00:00,  9.28it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 11.31it/s]
#                    all         10         10      0.915          1      0.995      0.848
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     197/199      1.06G    0.01637   0.007108   0.004695          7        256: 100% 12/12 [00:01<00:00, 10.27it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 10.69it/s]
#                    all         10         10      0.918          1      0.995      0.848
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     198/199      1.06G     0.0168   0.006501   0.005116          7        256: 100% 12/12 [00:01<00:00, 10.57it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  9.38it/s]
#                    all         10         10      0.911          1      0.995      0.848
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     199/199      1.06G    0.01726   0.006963   0.006306          6        256: 100% 12/12 [00:01<00:00,  8.40it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00, 11.56it/s]
#                    all         10         10      0.908          1      0.995      0.848
#
# 200 epochs completed in 0.079 hours.
# Optimizer stripped from runs/train/exp/weights/last.pt, 42.1MB
# Results saved to runs/train/exp

# %% [markdown]
# ## Detección en el testing

# %%
TEST_WEIGHTS = 'runs/train/exp/weights/last.pt'  # ver path en las ultimas lineas de la ejecución anterior
PATH_TEST    = '../data/images/test'

# %%
# !python detect.py --weights {TEST_WEIGHTS} --img 256 --conf 0.7 --source  {PATH_TEST} --save-txt --save-conf
# Out:
# detect: weights=['runs/train/exp/weights/last.pt'], source=../data/images/test, data=data/coco128.yaml, imgsz=[256, 256], conf_thres=0.7, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_csv=False, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-247-g3f02fde Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5m summary: 212 layers, 20881221 parameters, 0 gradients, 47.9 GFLOPs
# image 1/43 /content/data/images/test/11_0.jpg: 256x256 1 Aranero Coronado Chico, 10.4ms
# image 2/43 /content/data/images/test/11_1.jpg: 256x256 1 Aranero Coronado Chico, 12.4ms
# image 3/43 /content/data/images/test/14_1.jpg: 256x256 1 Aranero Coronado Chico, 9.3ms
# image 4/43 /content/data/images/test/15_0.jpg: 256x256 1 Aranero Coronado Chico, 12.2ms
# image 5/43 /content/data/images/test/17_1.jpg: 256x256 1 Aranero Coronado Chico, 9.3ms
# image 6/43 /content/data/images/test/18_0.jpg: 256x256 1 Bailarin Azul, 9.5ms
# image 7/43 /content/data/images/test/20_1.jpg: 256x256 1 Bailarin Azul, 9.4ms
# image 8/43 /content/data/images/test/21_0.jpg: 256x256 1 Bailarin Azul, 9.4ms
# image 9/43 /content/data/images/test/21_1.jpg: 256x256 1 Bailarin Azul, 9.6ms
# image 10/43 /content/data/images/test/22_0.jpg: 256x256 1 Bailarin Azul, 11.2ms
# image 11/43 /content/data/images/test/23_0.jpg: 256x256 1 Bailarin Azul, 16.1ms
# image 12/43 /content/data/images/test/24_0.jpg: 256x256 1 Bailarin Azul, 9.9ms
# image 13/43 /content/data/images/test/25_1.jpg: 256x256 1 Bailarin Azul, 10.5ms
# image 14/43 /content/data/images/test/28_1.jpg: 256x256 1 Bailarin Azul, 9.6ms
# image 15/43 /content/data/images/test/30_0.jpg: 256x256 1 Bailarin Naranja, 9.6ms
# image 16/43 /content/data/images/test/31_0.jpg: 256x256 1 Bailarin Naranja, 10.1ms
# image 17/43 /content/data/images/test/32_0.jpg: 256x256 1 Bailarin Naranja, 10.8ms
# image 18/43 /content/data/images/test/32_1.jpg: 256x256 1 Bailarin Naranja, 10.5ms
# image 19/43 /content/data/images/test/35_0.jpg: 256x256 1 Bailarin Naranja, 8.8ms
# image 20/43 /content/data/images/test/36_1.jpg: 256x256 1 Bailarin Naranja, 8.5ms
# image 21/43 /content/data/images/test/39_0.jpg: 256x256 1 Batara Pintado, 8.9ms
# image 22/43 /content/data/images/test/40_0.jpg: 256x256 1 Batara Pintado, 13.3ms
# image 23/43 /content/data/images/test/41_0.jpg: 256x256 1 Batara Pintado, 9.9ms
# image 24/43 /content/data/images/test/43_0.jpg: 256x256 1 Batara Pintado, 11.1ms
# image 25/43 /content/data/images/test/46_0.jpg: 256x256 2 Cardenal Comuns, 11.4ms
# image 26/43 /content/data/images/test/48_1.jpg: 256x256 1 Cardenal Comun, 11.8ms
# image 27/43 /content/data/images/test/49_0.jpg: 256x256 1 Cardenal Comun, 9.8ms
# image 28/43 /content/data/images/test/4_0.jpg: 256x256 1 Aguila Viuda, 9.3ms
# image 29/43 /content/data/images/test/50_1.jpg: 256x256 1 Cardenal Comun, 8.6ms
# image 30/43 /content/data/images/test/55_0.jpg: 256x256 1 Carpintero Garganta Estriada, 10.9ms
# image 31/43 /content/data/images/test/55_1.jpg: 256x256 1 Carpintero Garganta Estriada, 9.2ms
# image 32/43 /content/data/images/test/59_1.jpg: 256x256 1 Carpintero Garganta Estriada, 10.1ms
# image 33/43 /content/data/images/test/60_0.jpg: 256x256 1 Carpintero Garganta Estriada, 11.3ms
# image 34/43 /content/data/images/test/61_0.jpg: 256x256 1 Carpintero Garganta Estriada, 9.4ms
# image 35/43 /content/data/images/test/63_1.jpg: 256x256 1 Carpintero Garganta Estriada, 9.0ms
# image 36/43 /content/data/images/test/64_0.jpg: 256x256 1 Carpintero Garganta Estriada, 10.9ms
# image 37/43 /content/data/images/test/65_1.jpg: 256x256 1 Carpintero Garganta Estriada, 10.1ms
# image 38/43 /content/data/images/test/66_1.jpg: 256x256 1 Carpintero Garganta Estriada, 9.8ms
# image 39/43 /content/data/images/test/67_0.jpg: 256x256 1 Picaflor Cronova Violacea, 8.7ms
# image 40/43 /content/data/images/test/68_0.jpg: 256x256 1 Picaflor Cronova Violacea, 8.3ms
# image 41/43 /content/data/images/test/72_1.jpg: 256x256 1 Picaflor Cronova Violacea, 8.8ms
# image 42/43 /content/data/images/test/7_0.jpg: 256x256 1 Aguila Viuda, 11.8ms
# image 43/43 /content/data/images/test/9_1.jpg: 256x256 2 Aguila Viudas, 13.3ms
# Speed: 0.2ms pre-process, 10.3ms inference, 1.2ms NMS per image at shape (1, 3, 256, 256)
# Results saved to runs/detect/exp
# 43 labels saved to runs/detect/exp/labels

# %% [markdown]
# ## Estadísticas en validación

# %%
# !python val.py --weights {TEST_WEIGHTS} --conf 0.7 --data {YAMLFILE} --img {IMG_SIZE} --iou 0.25 --half
# Out:
# val: data=../data/data.yaml, weights=['runs/train/exp/weights/last.pt'], batch_size=32, imgsz=256, conf_thres=0.7, iou_thres=0.25, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=True, dnn=False
# WARNING ⚠️ confidence threshold 0.7 > 0.001 produces invalid results
# YOLOv5 🚀 v7.0-247-g3f02fde Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5m summary: 212 layers, 20881221 parameters, 0 gradients, 47.9 GFLOPs
# val: Scanning /content/data/labels/val.cache... 10 images, 0 backgrounds, 0 corrupt: 100% 10/10 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.29it/s]
#                    all         10         10          1          1      0.995      0.857
#           Aguila Viuda         10          1          1          1      0.995      0.895
#          Bailarin Azul         10          2          1          1      0.995      0.784
#       Bailarin Naranja         10          2          1          1      0.995      0.895
#         Cardenal Comun         10          3          1          1      0.995      0.874
# Carpintero Garganta Estriada         10          1          1          1      0.995      0.895
# Picaflor Cronova Violacea         10          1          1          1      0.995      0.796
# Speed: 0.1ms pre-process, 23.7ms inference, 1.3ms NMS per image at shape (32, 3, 256, 256)
# Results saved to runs/val/exp

# %%
import cv2
import matplotlib.pyplot as plt

I = cv2.imread('runs/val/exp/confusion_matrix.png') # ver path en las ultimas lineas de la ejecución anterior
plt.figure(figsize=(12,12))
plt.imshow(I)
plt.show()

# %% [markdown]
# ## Estadísticas en testing

# %%
# !python val.py --weights {TEST_WEIGHTS} --data {YAMLFILE} --img {IMG_SIZE} --iou 0.75 --task test
# Out:
# val: data=../data/data.yaml, weights=['runs/train/exp/weights/last.pt'], batch_size=32, imgsz=256, conf_thres=0.001, iou_thres=0.75, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-247-g3f02fde Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5m summary: 212 layers, 20881221 parameters, 0 gradients, 47.9 GFLOPs
# test: Scanning /content/data/labels/test.cache... 43 images, 0 backgrounds, 0 corrupt: 100% 43/43 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:00<00:00,  2.16it/s]
#                    all         43         45      0.976          1      0.995      0.822
#           Aguila Viuda         43          4      0.954          1      0.995      0.895
# Aranero Coronado Chico         43          5      0.974          1      0.995      0.843
#          Bailarin Azul         43          9      0.994          1      0.995      0.875
#       Bailarin Naranja         43          6      0.986          1      0.995      0.849
#         Batara Pintado         43          4      0.975          1      0.995      0.666
#         Cardenal Comun         43          5      0.986          1      0.995       0.87
# Carpintero Garganta Estriada         43          9      0.996          1      0.995      0.681
# Picaflor Cronova Violacea         43          3      0.942          1      0.995      0.895
# Speed: 0.0ms pre-process, 11.0ms inference, 1.7ms NMS per image at shape (32, 3, 256, 256)
# Results saved to runs/val/exp3

# %%
I = cv2.imread('runs/val/exp2/PR_curve.png')  # ver path en las ultimas lineas de la ejecución anterior
plt.figure(figsize=(12,12))
plt.imshow(I)
plt.show()

# %% [markdown]
# ## Despliegue de resultados
#
# Imágenes con detecciones incrustadas por YOLO, o incrustaciones manuales a partir de la salida de las clases.

# %%
def plot_boundingbox(iname,img_path,label_path):
    img_name = img_path +'/'+iname
    print('image:',img_name)
    X = cv2.imread(img_name)
    N = X.shape[0]
    M = X.shape[1]
    plt.figure(figsize=(12,12))
    plt.imshow(cv2.cvtColor(X, cv2.COLOR_BGR2RGB))
    plt.title(iname)
    lname = label_path+iname[:-4]+'.txt'
    print(' bbox:',lname)
    if os.path.isfile(lname):
        arr = np.loadtxt(lname)
        if len(arr.shape)==1:
            n = 1
        else:
            n = arr.shape[0]
        for k in range(n):
            if n>1:
                z = arr[k,:]
            else:
                z = arr
            cl = int(z[0]) # object class
            x = z[1]*M
            y = z[2]*N
            w2 = z[3]*M/2
            h2 = z[4]*N/2
            x1 = x-w2
            x2 = x+w2
            y1 = y-h2
            y2 = y+h2
            try:
                p = z[5]
                plt.plot([x1,x1,x2,x2,x1],[y1,y2,y2,y1,y1],'g')
                plt.text(x1,y1,"{} - {}".format(str(class_names[cl]), p),bbox=dict(facecolor='red', alpha=0.5))
            except:
                # Se guardaron etiquetas sin probabilidad
                # O se está leyendo un archivo de etiqueta manual
                plt.plot([x1,x1,x2,x2,x1],[y1,y2,y2,y1,y1],'g')
                plt.text(x1,y1,str(class_names[cl]),bbox=dict(facecolor='red', alpha=0.5))
    plt.show()

# %%
tpath = '../data/images/test/'
lpath = '../data/labels/test/'
img_names = dirfiles(tpath,'*.jpg')
i = 0

# %%
i = 15 # Indice para ver alguna en específico
# Acá las imágenes tienen el box incrustado por la red, abajo no. Lo ponemos nosotros.
iname = img_names[i]
img_path = 'runs/detect/exp' # ver path en las ultimas lineas de la ejecución de 'deteccion en testing'
label_path = lpath
plot_boundingbox(iname, img_path, label_path)
# Out:
# image: runs/detect/exp/31_0.jpg
#  bbox: ../data/labels/test/31_0.txt

# %%
iname = img_names[i]
img_path = '../data/images/test/'
label_path = 'runs/detect/exp/labels/' # ver path en las ultimas lineas de la ejecución anterior
plot_boundingbox(iname,img_path,label_path)
# Out:
# image: ../data/images/test//31_0.jpg
#  bbox: runs/detect/exp/labels/31_0.txt

# %% [markdown]
# # Detección en imágenes de prueba nuevas
#
# Se carga en nuevo directorio la(s) imagen(es) a probar y se corre `detect.py` como se corrió en uno de los pasos anteriores:

# %%
# %cd ..
# Out:
# /content

# %%
# Archivos pueden arrastrarse al área de trabajo o procesarse en local

# Version Online
# !wget https://github.com/AxelSkrauba/Taller_IA/raw/main/3_RNA_TransferLearning/OnlyTest_byGoogle.zip
# Out:
# --2023-12-01 22:15:42--  https://github.com/AxelSkrauba/Taller_IA/raw/main/3_RNA_TransferLearning/OnlyTest_byGoogle.zip
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/AxelSkrauba/Taller_IA/main/3_RNA_TransferLearning/OnlyTest_byGoogle.zip [following]
# --2023-12-01 22:15:43--  https://raw.githubusercontent.com/AxelSkrauba/Taller_IA/main/3_RNA_TransferLearning/OnlyTest_byGoogle.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 17612926 (17M) [application/zip]
# Saving to: ‘OnlyTest_byGoogle.zip’
#
# OnlyTest_byGoogle.z 100%[===================>]  16.80M  --.-KB/s    in 0.05s
#
# 2023-12-01 22:15:44 (328 MB/s) - ‘OnlyTest_byGoogle.zip’ saved [17612926/17612926]

# %%
# !unzip -qq OnlyTest_byGoogle.zip

# %%
# %cd yolov5
# Out:
# /content/yolov5

# %%
NEW_PATH_TEST = '../OnlyTest_byGoogle'
TEST_IMAGE    = 'AraneroCoronadoChico51.jpg'

# %%
# !python detect.py --weights {TEST_WEIGHTS} --img 350 --conf 0.5 --source  {NEW_PATH_TEST} --save-txt  --save-conf
# Out:
# detect: weights=['runs/train/exp/weights/last.pt'], source=../OnlyTest_byGoogle, data=data/coco128.yaml, imgsz=[350, 350], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_csv=False, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-247-g3f02fde Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5m summary: 212 layers, 20881221 parameters, 0 gradients, 47.9 GFLOPs
# WARNING ⚠️ --img-size [350, 350] must be multiple of max stride 32, updating to [352, 352]
# image 1/232 /content/OnlyTest_byGoogle/AguilaViuda1.jpg: 256x352 1 Cardenal Comun, 47.7ms
# image 2/232 /content/OnlyTest_byGoogle/AguilaViuda10.jpg: 352x352 (no detections), 12.7ms
# image 3/232 /content/OnlyTest_byGoogle/AguilaViuda11.jpg: 256x352 1 Aguila Viuda, 1 Cardenal Comun, 10.2ms
# image 4/232 /content/OnlyTest_byGoogle/AguilaViuda12.jpg: 256x352 1 Aguila Viuda, 10.1ms
# image 5/232 /content/OnlyTest_byGoogle/AguilaViuda13.jpg: 288x352 1 Aguila Viuda, 50.2ms
# image 6/232 /content/OnlyTest_byGoogle/AguilaViuda14.jpg: 256x352 1 Aguila Viuda, 10.2ms
# image 7/232 /content/OnlyTest_byGoogle/AguilaViuda15.jpg: 256x352 (no detections), 10.1ms
# image 8/232 /content/OnlyTest_byGoogle/AguilaViuda16.jpg: 256x352 (no detections), 10.1ms
# image 9/232 /content/OnlyTest_byGoogle/AguilaViuda17.jpg: 256x352 1 Aguila Viuda, 10.3ms
# image 10/232 /content/OnlyTest_byGoogle/AguilaViuda18.jpg: 256x352 (no detections), 10.1ms
# image 11/232 /content/OnlyTest_byGoogle/AguilaViuda19.jpg: 352x352 (no detections), 12.6ms
# image 12/232 /content/OnlyTest_byGoogle/AguilaViuda2.jpg: 352x352 1 Aguila Viuda, 12.5ms
# image 13/232 /content/OnlyTest_byGoogle/AguilaViuda20.jpg: 352x352 1 Aguila Viuda, 12.5ms
# image 14/232 /content/OnlyTest_byGoogle/AguilaViuda3.jpg: 256x352 (no detections), 10.2ms
# image 15/232 /content/OnlyTest_byGoogle/AguilaViuda4.jpg: 256x352 (no detections), 8.9ms
# image 16/232 /content/OnlyTest_byGoogle/AguilaViuda5.jpg: 352x352 1 Aguila Viuda, 9.8ms
# image 17/232 /content/OnlyTest_byGoogle/AguilaViuda6.jpg: 352x288 1 Cardenal Comun, 46.0ms
# image 18/232 /content/OnlyTest_byGoogle/AguilaViuda7.jpg: 256x352 1 Aguila Viuda, 7.9ms
# image 19/232 /content/OnlyTest_byGoogle/AguilaViuda8.jpg: 256x352 1 Aguila Viuda, 10.3ms
# image 20/232 /content/OnlyTest_byGoogle/AguilaViuda9.jpg: 352x352 (no detections), 9.8ms
# image 21/232 /content/OnlyTest_byGoogle/AraneroCoronadoChico23.jpg: 288x352 1 Aranero Coronado Chico, 8.9ms
# image 22/232 /content/OnlyTest_byGoogle/AraneroCoronadoChico24.jpg: 256x352 1 Aranero Coronado Chico, 8.5ms
# image 23/232 /content/OnlyTest_byGoogle/AraneroCoronadoChico25.jpg: 256x352 1 Aranero Coronado Chico, 7.9ms
# image 24/232 /content/OnlyTest_byGoogle/AraneroCoronadoChico26.jpg: 256x352 1 Aranero Coronado Chico, 8.0ms
# image 25/232 /content/OnlyTest_byGoogle/AraneroCoronadoChico27.jpg: 256x352 1 Aranero Coronado Chico, 9.6ms
# image 26/232 /content/OnlyTest_byGoogle/AraneroCoronadoChico29.jpg: 256x352 1 Bailarin Naranja, 7.9ms
# image 27/232 /content/OnlyTest_byGoogle/AraneroCoronadoChico30.jpg: 256x352 1 Aranero Coronado Chico, 7.9ms
# image 28/232 /content/OnlyTest_byGoogle/AraneroCoronadoChico31.jpg: 256x352 1 Aranero Coronado Chico, 8.5ms
# image 29/232 /content/OnlyTest_byGoogle/AraneroCoronadoChico32.jpg: 224x352 (no detections), 45.1ms
# image 30/232 /content/OnlyTest_byGoogle/AraneroCoronadoChico33.jpg: 256x352 (no detections), 7.9ms
# image 31/232 /content/OnlyTest_byGoogle/AraneroCoronadoChico34.jpg: 256x352 1 Aranero Coronado Chico, 7.9ms
# image 32/232 /content/OnlyTest_byGoogle/AraneroCoronadoChico35.jpg: 256x352 1 Aranero Coronado Chico, 7.9ms
# image 33/232 /content/OnlyTest_byGoogle/AraneroCoronadoChico36.jpg: 256x352 1 Aranero Coronado Chico, 7.9ms
# image 34/232 /content/OnlyTest_byGoogle/AraneroCoronadoChico37.jpg: 256x352 1 Aranero Coronado Chico, 7.9ms
# image 35/232 /content/OnlyTest_byGoogle/AraneroCoronadoChico38.jpg: 256x352 (no detections), 7.9ms
# image 36/232 /content/OnlyTest_byGoogle/AraneroCoronadoChico39.jpg: 256x352 1 Aranero Coronado Chico, 7.9ms
# image 37/232 /content/OnlyTest_byGoogle/AraneroCoronadoChico40.jpg: 256x352 1 Batara Pintado, 7.8ms
# image 38/232 /content/OnlyTest_byGoogle/AraneroCoronadoChico43.jpg: 256x352 1 Aranero Coronado Chico, 7.9ms
# image 39/232 /content/OnlyTest_byGoogle/AraneroCoronadoChico44.jpg: 288x352 (no detections), 8.9ms
# image 40/232 /content/OnlyTest_byGoogle/AraneroCoronadoChico45.jpg: 352x288 1 Aranero Coronado Chico, 8.9ms
# image 41/232 /content/OnlyTest_byGoogle/AraneroCoronadoChico46.jpg: 352x288 1 Aranero Coronado Chico, 8.9ms
# image 42/232 /content/OnlyTest_byGoogle/AraneroCoronadoChico47.jpg: 288x352 1 Aranero Coronado Chico, 11.3ms
# image 43/232 /content/OnlyTest_byGoogle/AraneroCoronadoChico48.jpg: 256x352 1 Aranero Coronado Chico, 9.6ms
# image 44/232 /content/OnlyTest_byGoogle/AraneroCoronadoChico49.jpg: 256x352 1 Aranero Coronado Chico, 7.9ms
# image 45/232 /content/OnlyTest_byGoogle/AraneroCoronadoChico50.jpg: 256x352 1 Aranero Coronado Chico, 7.9ms
# image 46/232 /content/OnlyTest_byGoogle/AraneroCoronadoChico51.jpg: 256x352 1 Aranero Coronado Chico, 7.9ms
# image 47/232 /content/OnlyTest_byGoogle/AraneroCoronadoChico52.jpg: 256x352 1 Aranero Coronado Chico, 8.5ms
# image 48/232 /content/OnlyTest_byGoogle/AraneroCoronadoChico53.jpg: 256x352 1 Aranero Coronado Chico, 7.8ms
# image 49/232 /content/OnlyTest_byGoogle/AraneroCoronadoChico55.jpg: 288x352 1 Aranero Coronado Chico, 8.9ms
# image 50/232 /content/OnlyTest_byGoogle/BailarinAzul56.jpg: 256x352 1 Bailarin Azul, 7.9ms
# image 51/232 /content/OnlyTest_byGoogle/BailarinAzul57.jpg: 352x288 1 Bailarin Azul, 8.9ms
# image 52/232 /content/OnlyTest_byGoogle/BailarinAzul58.jpg: 352x352 (no detections), 9.8ms
# image 53/232 /content/OnlyTest_byGoogle/BailarinAzul60.jpg: 288x352 1 Bailarin Azul, 8.9ms
# image 54/232 /content/OnlyTest_byGoogle/BailarinAzul61.jpg: 256x352 1 Bailarin Azul, 7.9ms
# image 55/232 /content/OnlyTest_byGoogle/BailarinAzul62.jpg: 352x256 (no detections), 46.7ms
# image 56/232 /content/OnlyTest_byGoogle/BailarinAzul63.jpg: 256x352 1 Bailarin Azul, 7.9ms
# image 57/232 /content/OnlyTest_byGoogle/BailarinAzul64.jpg: 256x352 1 Bailarin Azul, 7.9ms
# image 58/232 /content/OnlyTest_byGoogle/BailarinAzul65.jpg: 192x352 (no detections), 53.8ms
# image 59/232 /content/OnlyTest_byGoogle/BailarinAzul66.jpg: 256x352 1 Picaflor Cronova Violacea, 7.9ms
# image 60/232 /content/OnlyTest_byGoogle/BailarinAzul67.jpg: 256x352 1 Picaflor Cronova Violacea, 7.9ms
# image 61/232 /content/OnlyTest_byGoogle/BailarinAzul68.jpg: 256x352 1 Bailarin Azul, 7.9ms
# image 62/232 /content/OnlyTest_byGoogle/BailarinAzul69.jpg: 256x352 1 Aranero Coronado Chico, 7.9ms
# image 63/232 /content/OnlyTest_byGoogle/BailarinAzul70.jpg: 256x352 1 Bailarin Azul, 8.0ms
# image 64/232 /content/OnlyTest_byGoogle/BailarinAzul71.jpg: 352x256 1 Picaflor Cronova Violacea, 7.8ms
# image 65/232 /content/OnlyTest_byGoogle/BailarinAzul72.jpg: 352x256 (no detections), 7.7ms
# image 66/232 /content/OnlyTest_byGoogle/BailarinAzul73.jpg: 256x352 1 Bailarin Azul, 9.4ms
# image 67/232 /content/OnlyTest_byGoogle/BailarinAzul74.jpg: 256x352 1 Bailarin Azul, 7.9ms
# image 68/232 /content/OnlyTest_byGoogle/BailarinAzul75.jpg: 256x352 2 Bailarin Azuls, 8.0ms
# image 69/232 /content/OnlyTest_byGoogle/BailarinAzul76.jpg: 256x352 1 Bailarin Azul, 8.2ms
# image 70/232 /content/OnlyTest_byGoogle/BailarinAzul77.jpg: 256x352 1 Bailarin Azul, 7.9ms
# image 71/232 /content/OnlyTest_byGoogle/BailarinAzul78.jpg: 256x352 1 Bailarin Azul, 8.0ms
# image 72/232 /content/OnlyTest_byGoogle/BailarinAzul80.jpg: 320x352 1 Bailarin Azul, 52.0ms
# image 73/232 /content/OnlyTest_byGoogle/BailarinAzul81.jpg: 256x352 1 Bailarin Azul, 9.8ms
# image 74/232 /content/OnlyTest_byGoogle/BailarinAzul82.jpg: 224x352 1 Bailarin Azul, 11.8ms
# image 75/232 /content/OnlyTest_byGoogle/BailarinAzul83.jpg: 288x352 1 Bailarin Azul, 11.1ms
# image 76/232 /content/OnlyTest_byGoogle/BailarinAzul84.jpg: 320x352 1 Aranero Coronado Chico, 11.8ms
# image 77/232 /content/OnlyTest_byGoogle/BailarinAzul85.jpg: 352x352 1 Bailarin Azul, 12.1ms
# image 78/232 /content/OnlyTest_byGoogle/BailarinAzul86.jpg: 352x352 (no detections), 12.0ms
# image 79/232 /content/OnlyTest_byGoogle/BailarinAzul87.jpg: 352x352 1 Bailarin Azul, 12.0ms
# image 80/232 /content/OnlyTest_byGoogle/BailarinAzul88.jpg: 352x352 (no detections), 12.0ms
# image 81/232 /content/OnlyTest_byGoogle/BailarinAzul89.jpg: 352x352 (no detections), 12.0ms
# image 82/232 /content/OnlyTest_byGoogle/BailarinAzul90.jpg: 352x352 1 Picaflor Cronova Violacea, 12.0ms
# image 83/232 /content/OnlyTest_byGoogle/BailarinAzul91.jpg: 352x352 (no detections), 12.0ms
# image 84/232 /content/OnlyTest_byGoogle/BailarinAzul93.jpg: 352x288 (no detections), 11.0ms
# image 85/232 /content/OnlyTest_byGoogle/BailarinNaranja100.jpg: 256x352 1 Aranero Coronado Chico, 1 Bailarin Naranja, 9.7ms
# image 86/232 /content/OnlyTest_byGoogle/BailarinNaranja101.jpg: 256x352 1 Bailarin Naranja, 9.7ms
# image 87/232 /content/OnlyTest_byGoogle/BailarinNaranja102.jpg: 352x352 1 Bailarin Naranja, 12.1ms
# image 88/232 /content/OnlyTest_byGoogle/BailarinNaranja103.jpg: 256x352 1 Bailarin Naranja, 8.4ms
# image 89/232 /content/OnlyTest_byGoogle/BailarinNaranja104.jpg: 256x352 1 Bailarin Naranja, 8.3ms
# image 90/232 /content/OnlyTest_byGoogle/BailarinNaranja106.jpg: 320x352 1 Bailarin Naranja, 11.4ms
# image 91/232 /content/OnlyTest_byGoogle/BailarinNaranja108.jpg: 256x352 (no detections), 8.2ms
# image 92/232 /content/OnlyTest_byGoogle/BailarinNaranja109.jpg: 256x352 1 Bailarin Naranja, 8.0ms
# image 93/232 /content/OnlyTest_byGoogle/BailarinNaranja110.jpg: 256x352 1 Bailarin Naranja, 8.7ms
# image 94/232 /content/OnlyTest_byGoogle/BailarinNaranja111.jpg: 288x352 1 Bailarin Azul, 8.9ms
# image 95/232 /content/OnlyTest_byGoogle/BailarinNaranja113.jpg: 256x352 1 Bailarin Naranja, 8.4ms
# image 96/232 /content/OnlyTest_byGoogle/BailarinNaranja114.jpg: 256x352 1 Bailarin Naranja, 7.9ms
# image 97/232 /content/OnlyTest_byGoogle/BailarinNaranja115.jpg: 288x352 1 Bailarin Naranja, 8.9ms
# image 98/232 /content/OnlyTest_byGoogle/BailarinNaranja116.jpg: 288x352 1 Bailarin Naranja, 8.9ms
# image 99/232 /content/OnlyTest_byGoogle/BailarinNaranja117.jpg: 288x352 1 Bailarin Naranja, 8.9ms
# image 100/232 /content/OnlyTest_byGoogle/BailarinNaranja118.jpg: 352x288 1 Bailarin Naranja, 8.9ms
# image 101/232 /content/OnlyTest_byGoogle/BailarinNaranja119.jpg: 256x352 1 Bailarin Naranja, 9.4ms
# image 102/232 /content/OnlyTest_byGoogle/BailarinNaranja121.jpg: 320x352 1 Bailarin Naranja, 9.5ms
# image 103/232 /content/OnlyTest_byGoogle/BailarinNaranja122.jpg: 256x352 1 Bailarin Naranja, 7.9ms
# image 104/232 /content/OnlyTest_byGoogle/BailarinNaranja123.jpg: 256x352 1 Bailarin Naranja, 7.9ms
# image 105/232 /content/OnlyTest_byGoogle/BailarinNaranja124.jpg: 256x352 1 Bailarin Naranja, 7.9ms
# image 106/232 /content/OnlyTest_byGoogle/BailarinNaranja125.jpg: 256x352 1 Bailarin Naranja, 7.9ms
# image 107/232 /content/OnlyTest_byGoogle/BailarinNaranja126.jpg: 256x352 1 Bailarin Naranja, 7.9ms
# image 108/232 /content/OnlyTest_byGoogle/BailarinNaranja94.jpg: 256x352 1 Bailarin Naranja, 8.1ms
# image 109/232 /content/OnlyTest_byGoogle/BailarinNaranja95.jpg: 256x352 1 Bailarin Naranja, 7.9ms
# image 110/232 /content/OnlyTest_byGoogle/BailarinNaranja97.jpg: 288x352 1 Bailarin Naranja, 8.9ms
# image 111/232 /content/OnlyTest_byGoogle/BailarinNaranja98.jpg: 256x352 1 Bailarin Naranja, 8.0ms
# image 112/232 /content/OnlyTest_byGoogle/BailarinNaranja99.jpg: 352x352 (no detections), 9.8ms
# image 113/232 /content/OnlyTest_byGoogle/BataraPintado127.jpg: 352x192 (no detections), 48.6ms
# image 114/232 /content/OnlyTest_byGoogle/BataraPintado128.jpg: 320x352 (no detections), 9.6ms
# image 115/232 /content/OnlyTest_byGoogle/BataraPintado129.jpg: 352x352 1 Batara Pintado, 9.8ms
# image 116/232 /content/OnlyTest_byGoogle/BataraPintado130.jpg: 224x352 1 Batara Pintado, 8.4ms
# image 117/232 /content/OnlyTest_byGoogle/BataraPintado131.jpg: 256x352 1 Aranero Coronado Chico, 1 Batara Pintado, 8.0ms
# image 118/232 /content/OnlyTest_byGoogle/BataraPintado132.jpg: 256x352 1 Batara Pintado, 7.9ms
# image 119/232 /content/OnlyTest_byGoogle/BataraPintado133.jpg: 256x352 1 Cardenal Comun, 7.9ms
# image 120/232 /content/OnlyTest_byGoogle/BataraPintado134.jpg: 256x352 1 Batara Pintado, 8.5ms
# image 121/232 /content/OnlyTest_byGoogle/BataraPintado137.jpg: 352x352 1 Batara Pintado, 9.8ms
# image 122/232 /content/OnlyTest_byGoogle/BataraPintado138.jpg: 256x352 (no detections), 8.2ms
# image 123/232 /content/OnlyTest_byGoogle/BataraPintado139.jpg: 256x352 1 Batara Pintado, 7.9ms
# image 124/232 /content/OnlyTest_byGoogle/BataraPintado140.jpg: 320x352 (no detections), 9.5ms
# image 125/232 /content/OnlyTest_byGoogle/BataraPintado141.jpg: 352x352 (no detections), 9.8ms
# image 126/232 /content/OnlyTest_byGoogle/BataraPintado142.jpg: 288x352 (no detections), 8.9ms
# image 127/232 /content/OnlyTest_byGoogle/BataraPintado143.jpg: 288x352 1 Batara Pintado, 9.9ms
# image 128/232 /content/OnlyTest_byGoogle/BataraPintado144.jpg: 256x352 2 Batara Pintados, 8.2ms
# image 129/232 /content/OnlyTest_byGoogle/BataraPintado145.jpg: 288x352 (no detections), 8.4ms
# image 130/232 /content/OnlyTest_byGoogle/BataraPintado146.jpg: 352x352 (no detections), 8.6ms
# image 131/232 /content/OnlyTest_byGoogle/BataraPintado147.jpg: 224x352 1 Batara Pintado, 9.9ms
# image 132/232 /content/OnlyTest_byGoogle/BataraPintado148.jpg: 288x352 1 Batara Pintado, 8.4ms
# image 133/232 /content/OnlyTest_byGoogle/BataraPintado149.jpg: 256x352 1 Batara Pintado, 8.3ms
# image 134/232 /content/OnlyTest_byGoogle/BataraPintado150.jpg: 352x352 1 Batara Pintado, 8.6ms
# image 135/232 /content/OnlyTest_byGoogle/BataraPintado151.jpg: 352x352 (no detections), 8.5ms
# image 136/232 /content/OnlyTest_byGoogle/BataraPintado152.jpg: 352x352 (no detections), 8.5ms
# image 137/232 /content/OnlyTest_byGoogle/BataraPintado153.jpg: 352x352 1 Batara Pintado, 8.4ms
# image 138/232 /content/OnlyTest_byGoogle/BataraPintado154.jpg: 352x352 (no detections), 8.8ms
# image 139/232 /content/OnlyTest_byGoogle/BataraPintado155.jpg: 288x352 1 Batara Pintado, 7.9ms
# image 140/232 /content/OnlyTest_byGoogle/BataraPintado156.jpg: 288x352 1 Batara Pintado, 7.6ms
# image 141/232 /content/OnlyTest_byGoogle/BataraPintado157.jpg: 256x352 1 Aranero Coronado Chico, 1 Bailarin Naranja, 13.6ms
# image 142/232 /content/OnlyTest_byGoogle/BataraPintado158.jpg: 352x352 (no detections), 9.4ms
# image 143/232 /content/OnlyTest_byGoogle/BataraPintado159.jpg: 352x352 (no detections), 8.2ms
# image 144/232 /content/OnlyTest_byGoogle/BataraPintado160.jpg: 256x352 1 Batara Pintado, 8.3ms
# image 145/232 /content/OnlyTest_byGoogle/BataraPintado161.jpg: 352x352 (no detections), 8.4ms
# image 146/232 /content/OnlyTest_byGoogle/BataraPintado162.jpg: 256x352 1 Batara Pintado, 8.6ms
# image 147/232 /content/OnlyTest_byGoogle/BataraPintado163.jpg: 256x352 1 Batara Pintado, 7.6ms
# image 148/232 /content/OnlyTest_byGoogle/CardenalComun164.jpg: 256x352 1 Cardenal Comun, 8.0ms
# image 149/232 /content/OnlyTest_byGoogle/CardenalComun165.jpg: 256x352 1 Cardenal Comun, 7.8ms
# image 150/232 /content/OnlyTest_byGoogle/CardenalComun166.jpg: 352x352 (no detections), 9.7ms
# image 151/232 /content/OnlyTest_byGoogle/CardenalComun167.jpg: 352x224 (no detections), 48.3ms
# image 152/232 /content/OnlyTest_byGoogle/CardenalComun168.jpg: 288x352 1 Cardenal Comun, 8.5ms
# image 153/232 /content/OnlyTest_byGoogle/CardenalComun169.jpg: 256x352 1 Cardenal Comun, 8.2ms
# image 154/232 /content/OnlyTest_byGoogle/CardenalComun173.jpg: 352x256 1 Cardenal Comun, 8.1ms
# image 155/232 /content/OnlyTest_byGoogle/CardenalComun174.jpg: 352x256 1 Cardenal Comun, 8.0ms
# image 156/232 /content/OnlyTest_byGoogle/CardenalComun175.jpg: 256x352 1 Cardenal Comun, 8.1ms
# image 157/232 /content/OnlyTest_byGoogle/CardenalComun176.jpg: 352x352 1 Cardenal Comun, 8.9ms
# image 158/232 /content/OnlyTest_byGoogle/CardenalComun177.jpg: 192x352 1 Cardenal Comun, 7.9ms
# image 159/232 /content/OnlyTest_byGoogle/CardenalComun178.jpg: 352x288 1 Cardenal Comun, 8.1ms
# image 160/232 /content/OnlyTest_byGoogle/CardenalComun179.jpg: 256x352 1 Cardenal Comun, 8.7ms
# image 161/232 /content/OnlyTest_byGoogle/CardenalComun180.jpg: 256x352 2 Cardenal Comuns, 7.7ms
# image 162/232 /content/OnlyTest_byGoogle/CardenalComun181.jpg: 256x352 1 Cardenal Comun, 7.8ms
# image 163/232 /content/OnlyTest_byGoogle/CardenalComun182.jpg: 352x256 1 Cardenal Comun, 8.3ms
# image 164/232 /content/OnlyTest_byGoogle/CardenalComun184.jpg: 256x352 2 Cardenal Comuns, 7.9ms
# image 165/232 /content/OnlyTest_byGoogle/CardenalComun185.jpg: 256x352 (no detections), 7.5ms
# image 166/232 /content/OnlyTest_byGoogle/CardenalComun186.jpg: 224x352 1 Cardenal Comun, 7.9ms
# image 167/232 /content/OnlyTest_byGoogle/CardenalComun187.jpg: 256x352 (no detections), 7.7ms
# image 168/232 /content/OnlyTest_byGoogle/CardenalComun189.jpg: 320x352 1 Cardenal Comun, 7.9ms
# image 169/232 /content/OnlyTest_byGoogle/CardenalComun190.jpg: 256x352 1 Cardenal Comun, 8.0ms
# image 170/232 /content/OnlyTest_byGoogle/CardenalComun191.jpg: 224x352 1 Cardenal Comun, 7.8ms
# image 171/232 /content/OnlyTest_byGoogle/CardenalComun192.jpg: 288x352 1 Cardenal Comun, 7.9ms
# image 172/232 /content/OnlyTest_byGoogle/CardenalComun193.jpg: 288x352 1 Cardenal Comun, 7.9ms
# image 173/232 /content/OnlyTest_byGoogle/CardenalComun194.jpg: 224x352 1 Cardenal Comun, 7.8ms
# image 174/232 /content/OnlyTest_byGoogle/CardenalComun195.jpg: 256x352 1 Cardenal Comun, 8.1ms
# image 175/232 /content/OnlyTest_byGoogle/CardenalComun196.jpg: 224x352 1 Cardenal Comun, 11.0ms
# image 176/232 /content/OnlyTest_byGoogle/CardenalComun197.jpg: 256x352 1 Cardenal Comun, 7.9ms
# image 177/232 /content/OnlyTest_byGoogle/CardenalComun198.jpg: 256x352 1 Cardenal Comun, 7.7ms
# image 178/232 /content/OnlyTest_byGoogle/CardenalComun199.jpg: 256x352 1 Cardenal Comun, 7.3ms
# image 179/232 /content/OnlyTest_byGoogle/CardenalComun200.jpg: 352x288 1 Cardenal Comun, 8.0ms
# image 180/232 /content/OnlyTest_byGoogle/CardenalComun201.jpg: 288x352 1 Cardenal Comun, 8.7ms
# image 181/232 /content/OnlyTest_byGoogle/CarpinteroGargantaEstriada202.jpg: 352x288 (no detections), 8.2ms
# image 182/232 /content/OnlyTest_byGoogle/CarpinteroGargantaEstriada203.jpg: 256x352 1 Carpintero Garganta Estriada, 7.8ms
# image 183/232 /content/OnlyTest_byGoogle/CarpinteroGargantaEstriada204.jpg: 288x352 (no detections), 7.7ms
# image 184/232 /content/OnlyTest_byGoogle/CarpinteroGargantaEstriada205.jpg: 352x288 (no detections), 7.8ms
# image 185/232 /content/OnlyTest_byGoogle/CarpinteroGargantaEstriada206.jpg: 256x352 1 Carpintero Garganta Estriada, 7.8ms
# image 186/232 /content/OnlyTest_byGoogle/CarpinteroGargantaEstriada207.jpg: 256x352 1 Carpintero Garganta Estriada, 7.7ms
# image 187/232 /content/OnlyTest_byGoogle/CarpinteroGargantaEstriada208.jpg: 352x256 1 Carpintero Garganta Estriada, 13.2ms
# image 188/232 /content/OnlyTest_byGoogle/CarpinteroGargantaEstriada209.jpg: 256x352 1 Aguila Viuda, 7.9ms
# image 189/232 /content/OnlyTest_byGoogle/CarpinteroGargantaEstriada211.jpg: 256x352 (no detections), 7.8ms
# image 190/232 /content/OnlyTest_byGoogle/CarpinteroGargantaEstriada212.jpg: 352x352 1 Carpintero Garganta Estriada, 12.1ms
# image 191/232 /content/OnlyTest_byGoogle/CarpinteroGargantaEstriada213.jpg: 288x352 1 Carpintero Garganta Estriada, 8.6ms
# image 192/232 /content/OnlyTest_byGoogle/CarpinteroGargantaEstriada214.jpg: 352x288 (no detections), 8.3ms
# image 193/232 /content/OnlyTest_byGoogle/CarpinteroGargantaEstriada215.jpg: 352x256 1 Carpintero Garganta Estriada, 8.2ms
# image 194/232 /content/OnlyTest_byGoogle/CarpinteroGargantaEstriada216.jpg: 352x288 1 Carpintero Garganta Estriada, 8.2ms
# image 195/232 /content/OnlyTest_byGoogle/CarpinteroGargantaEstriada217.jpg: 352x224 1 Carpintero Garganta Estriada, 10.2ms
# image 196/232 /content/OnlyTest_byGoogle/CarpinteroGargantaEstriada218.jpg: 352x352 (no detections), 8.1ms
# image 197/232 /content/OnlyTest_byGoogle/CarpinteroGargantaEstriada219.jpg: 288x352 1 Cardenal Comun, 7.9ms
# image 198/232 /content/OnlyTest_byGoogle/CarpinteroGargantaEstriada222.jpg: 288x352 1 Carpintero Garganta Estriada, 7.8ms
# image 199/232 /content/OnlyTest_byGoogle/CarpinteroGargantaEstriada223.jpg: 288x352 1 Carpintero Garganta Estriada, 7.8ms
# image 200/232 /content/OnlyTest_byGoogle/CarpinteroGargantaEstriada225.jpg: 352x288 1 Carpintero Garganta Estriada, 8.5ms
# image 201/232 /content/OnlyTest_byGoogle/CarpinteroGargantaEstriada226.jpg: 352x288 1 Carpintero Garganta Estriada, 7.6ms
# image 202/232 /content/OnlyTest_byGoogle/CarpinteroGargantaEstriada227.jpg: 224x352 1 Carpintero Garganta Estriada, 8.2ms
# image 203/232 /content/OnlyTest_byGoogle/CarpinteroGargantaEstriada228.jpg: 352x256 1 Carpintero Garganta Estriada, 8.2ms
# image 204/232 /content/OnlyTest_byGoogle/CarpinteroGargantaEstriada229.jpg: 352x256 (no detections), 7.8ms
# image 205/232 /content/OnlyTest_byGoogle/PicaflorCronovaViolacea231.jpg: 256x352 1 Picaflor Cronova Violacea, 8.1ms
# image 206/232 /content/OnlyTest_byGoogle/PicaflorCronovaViolacea232.jpg: 352x288 (no detections), 7.9ms
# image 207/232 /content/OnlyTest_byGoogle/PicaflorCronovaViolacea233.jpg: 256x352 1 Picaflor Cronova Violacea, 8.1ms
# image 208/232 /content/OnlyTest_byGoogle/PicaflorCronovaViolacea234.jpg: 352x352 1 Picaflor Cronova Violacea, 8.0ms
# image 209/232 /content/OnlyTest_byGoogle/PicaflorCronovaViolacea235.jpg: 352x352 (no detections), 7.4ms
# image 210/232 /content/OnlyTest_byGoogle/PicaflorCronovaViolacea236.jpg: 352x320 (no detections), 46.8ms
# image 211/232 /content/OnlyTest_byGoogle/PicaflorCronovaViolacea237.jpg: 288x352 1 Picaflor Cronova Violacea, 8.0ms
# image 212/232 /content/OnlyTest_byGoogle/PicaflorCronovaViolacea238.jpg: 256x352 1 Aranero Coronado Chico, 8.1ms
# image 213/232 /content/OnlyTest_byGoogle/PicaflorCronovaViolacea239.jpg: 288x352 1 Picaflor Cronova Violacea, 8.0ms
# image 214/232 /content/OnlyTest_byGoogle/PicaflorCronovaViolacea241.jpg: 288x352 (no detections), 7.6ms
# image 215/232 /content/OnlyTest_byGoogle/PicaflorCronovaViolacea242.jpg: 320x352 (no detections), 7.9ms
# image 216/232 /content/OnlyTest_byGoogle/PicaflorCronovaViolacea243.jpg: 256x352 1 Picaflor Cronova Violacea, 8.4ms
# image 217/232 /content/OnlyTest_byGoogle/PicaflorCronovaViolacea244.jpg: 288x352 (no detections), 9.0ms
# image 218/232 /content/OnlyTest_byGoogle/PicaflorCronovaViolacea245.jpg: 352x352 (no detections), 8.0ms
# image 219/232 /content/OnlyTest_byGoogle/PicaflorCronovaViolacea246.jpg: 320x352 (no detections), 8.2ms
# image 220/232 /content/OnlyTest_byGoogle/PicaflorCronovaViolacea247.jpg: 256x352 1 Picaflor Cronova Violacea, 9.8ms
# image 221/232 /content/OnlyTest_byGoogle/PicaflorCronovaViolacea248.jpg: 256x352 (no detections), 7.4ms
# image 222/232 /content/OnlyTest_byGoogle/PicaflorCronovaViolacea249.jpg: 256x352 1 Batara Pintado, 8.1ms
# image 223/232 /content/OnlyTest_byGoogle/PicaflorCronovaViolacea251.jpg: 256x352 1 Aranero Coronado Chico, 11.5ms
# image 224/232 /content/OnlyTest_byGoogle/PicaflorCronovaViolacea252.jpg: 256x352 1 Picaflor Cronova Violacea, 8.0ms
# image 225/232 /content/OnlyTest_byGoogle/PicaflorCronovaViolacea253.jpg: 256x352 1 Picaflor Cronova Violacea, 7.6ms
# image 226/232 /content/OnlyTest_byGoogle/PicaflorCronovaViolacea254.jpg: 352x288 (no detections), 10.2ms
# image 227/232 /content/OnlyTest_byGoogle/PicaflorCronovaViolacea255.jpg: 352x256 (no detections), 8.6ms
# image 228/232 /content/OnlyTest_byGoogle/PicaflorCronovaViolacea256.jpg: 256x352 1 Picaflor Cronova Violacea, 8.8ms
# image 229/232 /content/OnlyTest_byGoogle/PicaflorCronovaViolacea257.jpg: 288x352 (no detections), 8.2ms
# image 230/232 /content/OnlyTest_byGoogle/PicaflorCronovaViolacea258.jpg: 320x352 (no detections), 9.8ms
# image 231/232 /content/OnlyTest_byGoogle/PicaflorCronovaViolacea259.jpg: 352x288 1 Picaflor Cronova Violacea, 10.7ms
# image 232/232 /content/OnlyTest_byGoogle/PicaflorCronovaViolacea260.jpg: 352x352 (no detections), 8.3ms
# Speed: 0.2ms pre-process, 10.5ms inference, 0.8ms NMS per image at shape (1, 3, 352, 352)
# Results saved to runs/detect/exp2
# 170 labels saved to runs/detect/exp2/labels

# %%
X = cv2.imread('runs/detect/exp2/'+TEST_IMAGE) # ver path en las ultimas lineas de la ejecución anterior
plt.figure(figsize=(12,12))
plt.imshow(cv2.cvtColor(X, cv2.COLOR_BGR2RGB))
plt.title(TEST_IMAGE)
plt.show()

# %%
label_path = 'runs/detect/exp2/labels/' # ver path en las ultimas lineas de la ejecución anterior
plot_boundingbox(TEST_IMAGE, NEW_PATH_TEST, label_path)
# Out:
# image: ../OnlyTest_byGoogle/AraneroCoronadoChico51.jpg
#  bbox: runs/detect/exp2/labels/AraneroCoronadoChico51.txt

# %% [markdown]
# ### Visualización en lote del resultado

# %% [markdown]
# Charlamos sobre resultados, contextos, alcance del modelo y diferentes porqués...

# %%
from random import randint
import cv2


tpath = '../OnlyTest_byGoogle/'
img_names = dirfiles(tpath,'*.jpg')

LIMIT = 10

for i in range(LIMIT):
    img = img_names[randint(0,len(img_names))]
    X = cv2.imread('runs/detect/exp2/'+img) # ver path en las ultimas lineas de la ejecución anterior
    plt.figure(figsize=(12,12))
    plt.imshow(cv2.cvtColor(X, cv2.COLOR_BGR2RGB))
    plt.title(img)
    plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.
